# %% [markdown]
# # This Notebook contains the python code that performs operations on database

# %% [markdown]
# ## Import all necessary libraries

# %%
# import data manipulation libraries use in data science and analytics
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import itertools

# This library allows us to display data in table in html format with relying on pandas
from IPython.display import display, HTML

# import psycopg library to talk to the database
import psycopg2

# import pydaantic for type checking and insuring typesafety 
from pydantic import (BaseModel, EmailStr, Field, SecretStr, ValidationError)
from typing import (Optional, Any, Dict, List, Tuple)

# import sqlalchemy to manage database connections and carry out db operations
from sqlalchemy import (create_engine, inspect, text, 
    String, Numeric, Date, DateTime, BigInteger, Integer, Boolean, Column, Table, MetaData)
from sqlalchemy.engine import Engine

# importing python-decouple to help us access the secrets from a .env file
from decouple import (config, Config, RepositoryEnv)
# import path lib to set path for the env file
from pathlib import Path

# generate realistic sythetic data
from faker import Faker
import random

# Get the Os type on which the python code is running on 
import platform
from enum import Enum
import psutil

# %% [markdown]
# ## Create database connection model and function to validate the database parameters.
# I could have fed the database creds to the function directly like people normally do, but I chose to use pydantic to enforce type safety and to make sure once the parameters are set they are not changed during the execution of the program. <br>
# - ```frozen=True``` : When frozen is set to ```True``` it tells pydantic that once the parameters are set they are not allowed to change.
# - ```default=None``` : If suppose nothing is passed in any of the field then None will be passed automatically since I set None to be the default value.

# %%
# A pydantic model for database connection
# The reason I am using frozen in the fields in this model is because I don't want the fields to change after its setup for the first time
class DbConnManagerModel (BaseModel):
    host : str = Field(default=None, examples=["localhost"], frozen=True)
    database : str = Field(default=None, examples=["db_name"], frozen=True)
    user : str = Field(default=None, examples=["username"], frozen=True)
    password : str = Field(default=None, examples=["your_password"], frozen=True)
    port : int = Field(default=None, examples=[5432], frozen=True)

# %% [markdown]
# ## Tell jupyter notebook where to look for .env file

# %% [markdown]
# Here I will have to tell jupyter notebook where to look for the env file otherwise it won't know from where should it get the credentials for the database.
# ### Explaination :
# #### RepositoryEnv:
# - This comes from the ```python-decouple``` library.
# - This library knows how to read a ```.env``` file.
# - It parses through the ```.env``` file and makes the key-value pair available.
# #### Config:
# - This ```Config``` library comes from ```python-decouple``` library.
# - ```Config``` is a wrapper around different configuration sources like (```.env``` files)
# - When I created ```Config(RepositoryEnv(env_path))``` I am telling it to load configuration values from the given ```.env``` file (via ```RepositoryEnv```)

# %% [markdown]
# ### **NOTICE :**
# If your os platform is windows and you have created an .env file using file explorer like what I used to do in linux then windows has a tendency adding ```.text``` after the env file so your env file becomes like this ```.env.txt```. Beware of this when trying to use windows file exporer to create an env file. Use Vs code or jupyter notebook instead to create a ```.env``` file. <br>
# I will have to look into it a bit more no biggy.

# %% [markdown]
# #### I am going to write a function that gets the Os type on which this python code is currently running on and change the path accordingly with respect to the type of Os its running on

# %%
class PlatformType(Enum):
    WINDOWS = "Windows"
    LINUX = "Linux"
    MACOS = "Darwin"

def locate_env_file() -> Config:
    current_os_type = platform.system()
    if current_os_type == PlatformType.LINUX.value:
        print("Running on Linux")
        # The path below is an arch linux specific path
        env_path = Path("/home/aditya/github/credencys-training-pyspark/python/database_operation/.env")
    elif current_os_type == PlatformType.WINDOWS.value:
        print("Running on Windows")
        # The path below is windows specific
        env_path = Path("D:/training/credencys-training-pyspark/python/database_operation/.env")
    elif current_os_type == PlatformType.MACOS.value:
        print("Running on macOS")
        # Add the path for the env file that is specific for macOs
    else:
        print("Unknown platform detected!")        
    
    return Config(RepositoryEnv(env_path))

config = locate_env_file()
# Out:
# Running on Linux

# %% [markdown]
# ## Create a database connection using sql alchemy and create a connection object

# %%
# get the database connection prameters from the .env file and create a dictionary out of it
db_connection_params = {
    "host":config('host'),
    "database":config('database'),
    "user":config('user'),
    "password":config('password'),
    "port":config('port'),
}

# create a function to manage database connection
def database_engine(model_config:DbConnManagerModel) -> Engine:
    try:
        # validate connection parameters before creating a database connection object
        DBConnObj = DbConnManagerModel.model_validate(db_connection_params)
        print(f"DBConnObj : {DBConnObj}")
    
        # create a database engine
        engine = create_engine(
            f"postgresql+psycopg2://{DBConnObj.user}:{DBConnObj.password}@{DBConnObj.host}:{DBConnObj.port}/{DBConnObj.database}"
        )
        return engine
    except Exception as e:
        raise RuntimeError(f"failed to make connection with the database : {e}")

# create an databse engine object
engine_obj = database_engine(db_connection_params)
# Out:
# DBConnObj : host='localhost' database='training' user='postgres' password='1212' port=5432

# %% [markdown]
# ## Create a function to display data
# Before I move forward with firing up sql commands from python and make changes in the database I want to create a common function which will be used throughout this entire notebook to display data nicely in a table beautifully integrated in this notebook just like pandas. <br> This function will be responsible to display the incoming data from the database in a table in jupyter notebook using html and css for this I am using IPython
# - The reason I am going to display data by manually creating table in html and inserting it in this notebook's output window using IPython library instead of using pandas because I want to fire up raw sql queries and I don't want to rely on panda's function to carry out sql operations in the database. I wanted to do it manually using sqlAlchemy.
#
# ### Explaination :
# - ```display(HTML(html))``` :
#     - ```HTML(html)``` → takes the raw HTML string and tells Jupyter: “Render this as HTML, not plain text.”
#     - ```display(...)``` → is the IPython/Jupyter function that actually shows the formatted output in the notebook cell output area. Without this, you’d just see the raw string like.

# %%
# Create a function which is use the data returned by the "read_db_table_data" function
# to display the data nicely in a table using html code 
class DisplayDataModel(BaseModel):
    headers : List[str]
    rows : List[Tuple[Any,...]]
    
def display_data(display_model_config:DisplayDataModel) -> None:
    html = "<table border='1' style='border-collapse: collapse;'>"
    # Header row
    html += "<tr><th>S.no</th>" + "".join([f"<th>{h}</th>" for h in display_model_config.headers]) + "</tr>"
    # Data rows
    # using enumerate to get key value pairs on serial no and the actual data
    for i, row in enumerate(display_model_config.rows,start=1):  # limit rows for readability
        html += f"<tr><td>{i}</td>" + "".join([f"<td>{col}</td>" for col in row]) + "</tr>"
    html += "</table>"
    display(HTML(html))

# %% [markdown]
# ## **Create a table in the database**

# %% [markdown]
# ## Method 1 : Create the table using raw sql query without using sql alchemy models

# %% [markdown]
# ### Create a common function to execute all of sql queries from python directly into the postgreSql database
# #### Explaination : ```connection.execute(text(query_model.query),query_model.params or {})```
# - ```text(query_model.query)```
#     - Wraps the raw SQL string in a SQLAlchemy TextClause object.
#     - This tells SQLAlchemy, “This is a text-based SQL statement that can accept parameters.”
# - ```query_model.params```
#     - This is a list of dictionaries — one dictionary per row.
#     - SQLAlchemy automatically detects that and performs a bulk insert.

# %%
class ExecQueryModel(BaseModel):
    engine:Engine
    query:str=Field(default=None)
    params: Optional[List[Dict]] = None
    model_config={
        "arbitrary_types_allowed":True
    }

def exec_sql_query_fun(query_model:ExecQueryModel) -> Dict:
    try:
        with query_model.engine.connect() as connection:
            result = connection.execute(text(query_model.query),query_model.params or {})
            # Auto-commit only when DDL or DML commands are fired not Select commands
            if query_model.query.strip().lower().startswith(("insert","update","delete","create","alter","drop","truncate")):
                connection.commit()
            if query_model.query.strip().lower().startswith(("select")):
                rows = result.mappings().all()
                if not rows:
                    return{"status":False,"error":"no data found!"}
                # Extract headers from keys of the first row
                headers = list(rows[0].keys())
                # Convert rows dicts to tuples (ordered by headers)
                rows_tuples = [tuple(row[h] for h in headers) for row in rows]
                display_model_obj = DisplayDataModel(headers=headers,rows=rows_tuples)
                html_table = display_data(display_model_obj)
                return {"status": True}
        return {"status":True}
    except Exception as e:
        return {"status":False,"error":e}

# %% [markdown]
# ### Explaination :
# The reason why I am only commiting when ```insert```, ```update```, ```delete``` etc... apart from ```select``` because in DDL/DML operations in order to make sure that the changes in the database persists after the connection is closed with the database we have to explicitly commit changes in the database. the ```select``` query don't need any sort of commit hence I am avoiding any unecessary commit statement and reduce the overhead in the database.
#
# #### Why use ```result.mappings.all()```?
# The reason why I am using ```result.mappings.all()``` so that after running ```select``` statement I get result like this ```{'city': 'New York', 'country': 'USA'} ``` instead of this ```('New York', 'USA')```

# %% [markdown]
# ### Create a table :
# Here I am going to fire up raw sql query to crate a table in the database

# %%
create_table_string = """
CREATE TABLE customers (
customer_id SERIAL PRIMARY KEY,
city VARCHAR(40),
state_province VARCHAR(50),
country VARCHAR(50),
region VARCHAR(50)
);
"""

exec_query = ExecQueryModel(engine=engine_obj, query=create_table_string)
exec_sql_query_fun(exec_query)
# Out:
# {'status': True}

# %% [markdown]
# ### Insert data in the customers table:

# %% [markdown]
# #### First lets insert the data using sql query in the customers tablle in the database:

# %%
insert_data_string = """
INSERT INTO customers (city, state_province,country,region) VALUES
('New York', 'New York', 'USA', 'North America'),
('Los Angeles', 'California', 'USA', 'North America'),
('Chicago', 'Illinois', 'USA', 'North America'),
('Houston', 'Texas', 'USA', 'North America'),
('Phoenix', 'Arizona', 'USA', 'North America');
"""

exec_query = ExecQueryModel(engine=engine_obj, query=insert_data_string)
exec_sql_query_fun(exec_query)
# Out:
# {'status': True}

# %% [markdown]
# #### Lets automate the process and insert a data with randomization that is closer to the realworld
# Here in this case I am using faker
# - I created a dictionary that contains the countries reagion wise
# - Then I created a function that accepts how many rows of data should it generate
# - The function here will return a dictionary that has status and rows_data where status tells us if the operation has suceeded or not and rows_data contains the actual data in it.
# - I am randomizing the selection of regions keys and countries and then using faker library to generate cities and state accordingly
# - The final result will be a list of dictionaries.
# - I have created a query to insert data in the customers table where I have used placeholders
# - Then I passed the generated list of dictionaries as params and sql_query_string in this function ```exec_sql_query_fun``` via pydantic data model class

# %%
fake = Faker()

regions = {
    "North America": ["USA", "Canada", "Mexico"],
    "Europe": ["United Kingdom", "France", "Germany", "Italy", "Spain"],
    "Asia": ["India", "China", "Japan", "South Korea", "Singapore"],
    "South America": ["Brazil", "Argentina", "Chile", "Colombia", "Peru"],
    "Africa": ["South Africa", "Nigeria", "Kenya", "Egypt", "Morocco"],
    "Oceania": ["Australia", "New Zealand", "Fiji"]
}

class GenerateCustomersDataModel(BaseModel):
    no_of_rows : int = Field(default=0)

def generate_customers_data(data_gen_config : GenerateCustomersDataModel) -> Dict:
    try:
        rows = []
        for _ in range(data_gen_config.no_of_rows):
            region = random.choice(list(regions.keys()))
            country = random.choice(regions[region])
            city = fake.city()
            state = fake.state()
            rows.append({"city": city, "state": state, "country": country, "region": region})
        return {"status":True,"rows_data":rows}
    except Exception as e:
        return {"status":False,"error":e}
        
# Generate rows
rows_gen_obj = GenerateCustomersDataModel(no_of_rows=200)
data = generate_customers_data(rows_gen_obj)

insert_query = """
INSERT INTO customers (city, state_province, country, region)
VALUES (:city, :state, :country, :region)
"""

exec_query = ExecQueryModel(engine=engine_obj, query=insert_query, params=data.get("rows_data"))
exec_sql_query_fun(exec_query)
# Out:
# {'status': True}

# %% [markdown]
# #### Loading data from a csv file into their respective tables in the database
# For this I am going to use pandas and generate a dataFrame from the csv file and then write the dataFrame into the database using pandas. <br>
# Since the way of writing path changes depending on which platform you are working on I am going to make sure that the python code that I am writing works wheather its working on windows , linux or macos.

# %%
class LoadDataModel(BaseModel):
    csv_file_name : str = Field(default="")

def load_customers_data_from_csv(load_data_model_config:LoadDataModel) -> pd.DataFrame:
    if load_data_model_config.csv_file_name == "":
      raise ValueError("File name of the csv file is required to be able to load data into the dataFrame!")  
    current_os_type = platform.system()
    if current_os_type == PlatformType.LINUX.value:
        print("Running on Linux")
        # The path below is an arch linux specific path
        csv_customers_df=pd.read_csv(f"/home/aditya/github/credencys-training-pyspark/Database_related_training/Advanced+SQL+Querying/Course Materials/Data/{load_data_model_config.csv_file_name}.csv")
    elif current_os_type == PlatformType.WINDOWS.value:
        print("Running on Windows")
        # The path below is windows specific
        csv_customers_df=pd.read_csv(f"D:/training/credencys-training-pyspark/python/database_operation/Data/{load_data_model_config.csv_file_name}.csv")
    elif current_os_type == PlatformType.MACOS.value:
        print("Running on macOS")
        # Add the path for the env file that is specific for macOs
    else:
        print("Unknown platform detected!")        
    
    return csv_customers_df

load_data_csv_config = LoadDataModel(csv_file_name="customers")
customers_df = load_customers_data_from_csv(load_data_csv_config)
customers_df
# Out:
# Running on Linux
#       customer_id           city state_province        country    region
# 0           39278     Naperville       Illinois  United States  Interior
# 1           21102      Henderson       Kentucky  United States      Gulf
# 2           21240    Los Angeles     California  United States   Pacific
# 3           32368     Huntsville          Texas  United States  Interior
# 4           25832         Laredo          Texas  United States  Interior
# ...           ...            ...            ...            ...       ...
# 3187        28273     Long Beach     California  United States   Pacific
# 3188        21058        Edmonds     Washington  United States   Pacific
# 3189        29589  New York City       New York  United States  Atlantic
# 3190        37054        Anaheim     California  United States   Pacific
# 3191        16648       Columbus        Indiana  United States  Interior
#
# [3192 rows x 5 columns]

# %% [markdown]
# #### DROP TABLE
# Here I am going to create tables using sql alchemy without using any raw sql queries like what I did last time

# %% [markdown]
# #### But before I load data in the cutomers table I have to drop the table in the database:
# Since in the earlier steps I had created a table using sql query ```CREATE TABLE``` command I have to drop the table before loading data into the database in the customers table. The reason I am doing so is because as you can see in the code below :
# ```python
# customers = Table(
#     "customers",metadata,
#     Column("customer_id",BigInteger,primary_key=True),
#     Column("city",String(255),nullable=False),
#     Column("state_province",String(255),nullable=False),
#     Column("country",String(255),nullable=False),
#     Column("region",String(255),nullable=False),
# )
# ```
#
# <br>
#
# Here I have defined a customers table using sql alchemy instead of raw sql query. and in the line where I have written this code
# ```python
# if not inspector.has_table(write_df_model.table_name):
#     metadata.create_all(engine)
# ```
#
# <br>
#
# This piece of code will check if the table is present or not if not then it will create the customers table in the database. I want to drop the old table and create a new customers table in the database using sql alchemy schema hence I am doing this.

# %%
drop_customers_table_query_string = """
DROP TABLE customers;
"""
exec_query = ExecQueryModel(engine=engine_obj, query=drop_customers_table_query_string)
exec_sql_query_fun(exec_query)
# Out:
# {'status': True}

# %% [markdown]
# ## Method 2 : Create the table using sql alchemy models

# %%
metadata = MetaData()

# This will create the customers table in the database
customers = Table(
    "customers",metadata,
    Column("customer_id",BigInteger,primary_key=True),
    Column("city",String(255),nullable=False),
    Column("state_province",String(255),nullable=False),
    Column("country",String(255),nullable=False),
    Column("region",String(255),nullable=False),
)

# Creating a model for accepting the parameters to insert the data into the table from the df
class WriteDfToDbModel(BaseModel):
    df:pd.DataFrame=Field(default=None)
    table_name:str=Field(default=None)
    index:bool=Field(default=False)
    if_exists:str=Field(default=False)
    engine:Engine
    model_config={
        "arbitrary_types_allowed":True
    }

def write_df_to_db(write_df_model:WriteDfToDbModel) -> Dict:
    if write_df_model.df is None or write_df_model.df.empty:
        return {"status":False,"error":"DataFrame is required and cannnot be empty!"}
    if not write_df_model.table_name:
        return {"status":False, "error":"table_name is required and cannot be empty!"}
    if write_df_model.table_name:
        try:
            inspector = inspect(write_df_model.engine)
            # This will create the tables if not present in the database
            if not inspector.has_table(write_df_model.table_name):
                metadata.create_all(engine)
            # removes the id (primary key column from the database) if some data is already exists in the table to avoid any conflict
            if "id" in write_df_model.df.columns:
                write_df_model.df = write_df_model.df.drop(columns=["id"])
            write_df_model.df.to_sql(name=write_df_model.table_name,con=write_df_model.engine, index=write_df_model.index, if_exists=write_df_model.if_exists)
        except Exception as e:
            return {"status":False,"error":e}

# %% [markdown]
# ### Lets insert data into the database from csv file

# %%
table_name="customers"
engine=engine_obj
if_exists="append"
index=False
dataFrame=customers_df
write_to_db = WriteDfToDbModel(df=dataFrame,table_name=table_name,engine=engine,if_exists=if_exists,index=index)
write_df_to_database = write_df_to_db(write_to_db)

# %% [markdown]
# ### This method works well but it consumes a lot of memory because the dataFrame generated is extremely large.
# Right now the dataFrame generated from the csv file is small but in case where we have millions of data to deal with this method is going to fail because of shortage of memory or RAM in the system.
#
# ### Let's check the amount of ram taken by the dataFrame called ```customers_df```.

# %%
customers_df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     3192 non-null   int64
#  1   city            3192 non-null   object
#  2   state_province  3192 non-null   object
#  3   country         3192 non-null   object
#  4   region          3192 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 754.1 KB

# %%
mem_mb = customers_df.memory_usage(deep=True).sum() / (1024 * 1024)
print(f"Memory used by DataFrame: {mem_mb:.2f} MB")
# Out:
# Memory used by DataFrame: 0.74 MB

# %% [markdown]
# As you can see the dataFrame generated from the csv file is taking 754kb of space in RAM. I bet I could do better.

# %% [markdown]
# ### TRUNCATE table
# Last time I have dropped the customers table because I wanted to check if the schema thatI had created using sql alchemy is detecting the presence of the customers table and creating the table accordingly or not. <br>
# This time I only want the data to be deleted from the customers table and I want to keep the schema of the customers table intact hence I am going to truncate the table.

# %%
truncate_customers_table_query_string = """
TRUNCATE TABLE customers;
"""
exec_query = ExecQueryModel(engine=engine_obj, query=truncate_customers_table_query_string)
exec_sql_query_fun(exec_query)
# Out:
# {'status': True}

# %%
class CsvFilePathModel(BaseModel):
    csv_file_name : str = Field(default="")

# This function is responsible of getting the full path of the csv file given the file name
def get_csv_file_path(get_csv_file_path_model:CsvFilePathModel) -> str:
    if get_csv_file_path_model.csv_file_name == "":
      raise ValueError("File name of the csv file is required to be able to load data into the dataFrame!")  
    current_os_type = platform.system()
    if current_os_type == PlatformType.LINUX.value:
        print("Running on Linux")
        # The path below is an arch linux specific path
        csv_file_path = f"/home/aditya/github/credencys-training-pyspark/Database_related_training/Advanced+SQL+Querying/Course Materials/Data/{get_csv_file_path_model.csv_file_name}.csv"
    elif current_os_type == PlatformType.WINDOWS.value:
        print("Running on Windows")
        # The path below is windows specific
        csv_file_path = f"D:/training/credencys-training-pyspark/python/database_operation/Data/{get_csv_file_path_model.csv_file_name}.csv"
    elif current_os_type == PlatformType.MACOS.value:
        print("Running on macOS")
        # Add the path for the env file that is specific for macOs
    else:
        print("Unknown platform detected!")        
    
    return csv_file_path

metadata = MetaData()

# Create the tables if the tables does not exists in the database:
# This will create the customers table in the database
customers = Table(
    "customers",metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("customer_id",BigInteger,unique=True),
    Column("city",String(255),nullable=False),
    Column("state_province",String(255),nullable=False),
    Column("country",String(255),nullable=False),
    Column("region",String(255),nullable=False),
)
# This will create the products table in the database
products = Table(
    "products", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("product_id",String(255),unique=True),
    Column("product_name",String(255),nullable=True),
    Column("factory",String(255),nullable=True),
    Column("division",String(255),nullable=True),
    Column("unit_price",Numeric(10,3),nullable=True)
)
# This will create the orders table in the database
orders = Table(
    "orders", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("transaction_id",String(255),unique=True),
    Column("customer_id",BigInteger,unique=False),
    Column("order_id",String(255),unique=False),
    Column("order_date",Date,nullable=True),
    Column("product_id",String(255),unique=False),
    Column("units",Integer,nullable=True)
)
# This will create a country_stats table in the database
country_stats = Table(
    "country_stats", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("country", String(90),nullable=True),
    Column("continent", String(90),nullable=True),
    Column("population", BigInteger,nullable=True),
    Column("urban_population", BigInteger,nullable=True),
    Column("land_area_km2", BigInteger,nullable=True),
    Column("unemployment_rate", Numeric(10,2),nullable=True),
    Column("fertility_rate", Numeric(10,2),nullable=True),
    Column("infant_mortality", Numeric(10,2),nullable=True),
    Column("life_expectancy", Numeric(10,2),nullable=True),
    Column("physicians_per_thousand", Numeric(10,2),nullable=True),
)
# This will create a happiness_scores table in the database
happiness_scores = Table(
    "happiness_scores", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("year", Integer,nullable=True),
    Column("country", String(90),nullable=True),
    Column("region",String(90),nullable=True),
    Column("happiness_score", Numeric(10,5),nullable=True),
    Column("gdp_per_capita", Numeric(10,5),nullable=True),
    Column("social_support", Numeric(10,5),nullable=True),
    Column("healthy_life_expectancy", Numeric(10,5),nullable=True),
    Column("freedom_to_make_life_choices", Numeric(10,5),nullable=True),
    Column("generosity", Numeric(10,5),nullable=True),
    Column("perceptions_of_corruption", Numeric(10,5),nullable=True),
)
# This will create a inflation_rates table in the database
inflation_rates = Table(
    "inflation_rates", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("year", Integer,nullable=True),
    Column("country_name", String(90),nullable=True),
    Column("inflation_rate", String(90),nullable=True),
)
# This will create a players table in the database
players = Table(
    "players", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("playerID",String(255),nullable=True),
    Column("birthYear",Integer,nullable=True),
    Column("birthMonth",Integer,nullable=True),
    Column("birthDay",Integer,nullable=True),
    Column("birthCountry",String(255),nullable=True),
    Column("birthState",String(255),nullable=True),
    Column("birthCity",String(255),nullable=True),
    Column("deathYear",Integer,nullable=True),
    Column("deathMonth",Integer,nullable=True),
    Column("deathDay",Integer,nullable=True),
    Column("deathCountry",String(255),nullable=True),
    Column("deathState",String(255),nullable=True),
    Column("deathCity",String(255),nullable=True),
    Column("nameFirst",String(255),nullable=True),
    Column("nameLast",String(255),nullable=True),
    Column("nameGiven",String(255),nullable=True),
    Column("weight",Numeric(10,3),nullable=True),
    Column("height",Numeric(10,3),nullable=True),
    Column("bats",String(1),nullable=True),
    Column("throws",String(1),nullable=True),
    Column("debut",Date,nullable=True),
    Column("finalGame",Date,nullable=True),
    Column("retroID",String(255),nullable=True),
    Column("bbrefID",String(255),nullable=True),
)
# This will create a salaries table in the database
salaries = Table(
    "salaries", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("yearID",Integer,nullable=True),
    Column("teamID",String(3),nullable=True),
    Column("lgID",String(3),nullable=True),
    Column("playerID",String(200),nullable=True),
    Column("salary",Numeric(20,3),nullable=True)
)
# This will create a school_details table in the database
school_details = Table(
    "school_details", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("schoolID", String(200),nullable=True),
    Column("name_full",String(255),nullable=True),
    Column("city",String(100),nullable=True),
    Column("state",String(100),nullable=True),
    Column("country",String(100),nullable=True),
)
# This will crete a schools table in the database
schools = Table(
    "schools", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("playerID",String(200),nullable=True),
    Column("schoolID",String(200),nullable=True),
    Column("yearID",Integer,nullable=True),
)
# This will create a student_grades table in the database
student_grades = Table(
    "student_grades",metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("semester_id",String(200),nullable=True),
    Column("class_id",BigInteger,nullable=True),
    Column("department",String(100),nullable=True),
    Column("class_name",String(100),nullable=True),
    Column("student_id",BigInteger,nullable=True),
    Column("final_grade",Numeric(10,3),nullable=True),
)
# This will create a students table in the database
students = Table(
    "students", metadata,
    Column("id",BigInteger,primary_key=True,autoincrement=True),
    Column("student_name",String(200),nullable=True),
    Column("grade_level",Integer,nullable=True),
    Column("gpa",Numeric(8,4),nullable=True),
    Column("school_lunch",Boolean,nullable=True),
    Column("birthday",Date,nullable=True),
    Column("email",String(255),nullable=True),
)

# I have set if_exists default value to be "append" so by default it will insert data in the database in append mode
class WriteDataToDBFromCSVModel(BaseModel):
    chunksize:int=Field(default=50)
    table_name:str=Field(default=None)
    csv_file_path:str=Field(default="")
    if_exists:str=Field(default="append")
    index:bool=Field(default=False)
    engine:Engine
    model_config={
        "arbitrary_types_allowed":True
    }

# this function is a memory effitient function that loads data from a csv file into the database
def load_data_from_csv(load_data_from_csv_model:WriteDataToDBFromCSVModel)-> Dict:
    try:
        # This will create the tables if not present in the database
        inspector = inspect(load_data_from_csv_model.engine)
        if not inspector.has_table(load_data_from_csv_model.table_name):
            metadata.create_all(engine)
            
        total_rows=0
        chunk_no=0
        # for monitoring memory usage
        process=psutil.Process()
        for chunk_df in pd.read_csv(load_data_from_csv_model.csv_file_path, chunksize=load_data_from_csv_model.chunksize):
            chunk_no += 1
            
            # print dataFrame chunk info
            chunk_mem = chunk_df.memory_usage(deep=True).sum() / (1024*1024)
            print(f"df chunk {chunk_no} -> rows {len(chunk_df)}, size: {chunk_mem:.2f} MB")
    
            # current process memory
            proc_memory = process.memory_info().rss / (1024*1024)
            print(f"current process memory usage : {proc_memory:.2f} MB")

            # Convert to datetime.date format (only date, no time)
            date_columns = ["debut", "finalGame","order_date","birthday"]
            for col in date_columns:
                if col in chunk_df.columns:
                    chunk_df[col] = pd.to_datetime(
                        chunk_df[col],
                        format="%Y-%m-%d",   # adjust format as needed
                        errors="coerce"
                    ).dt.date

            # Convert "Yes" or "yes" and "No" or "no" into True or False respectively
            boolean_columns=["school_lunch"]
            for col in boolean_columns:
                if col in chunk_df.columns:
                    chunk_df[col] = chunk_df[col].map({"Yes":True,"yes":True,"No":False,"no":False})
    
            # drop id column that represents primary key if present in the dataFrame
            ids = ["id"]
            cols_to_drop = [col for col in ids if col in chunk_df.columns]
            if cols_to_drop:
               chunk_df = chunk_df.drop(columns=cols_to_drop)
    
            # write to sql
            chunk_df.to_sql(
                name=load_data_from_csv_model.table_name,
                con=load_data_from_csv_model.engine,
                index=load_data_from_csv_model.index,
                if_exists=load_data_from_csv_model.if_exists
            )
            total_rows += len(chunk_df)
        return {"status":True,"message":f"\n Done loading all {total_rows} rows into '{table_name}'."}
    except Exception as e:
        return {"status":False,"error":e}

# %% [markdown]
# #### Analysis:
# - ```psutil``` is a python's system monitoring library.
# - ```process = psutil.process()``` It is used to create an object of my currently running python process
# - ```process.memory_info().rss``` tells how much memory is consumed by this process in bytes
# - ```chunk_df.memory_usage(deep=True).sum()``` This is a Pandas function that measures the memory used by one DataFrame only.
# - ```process.memory_info().rss``` vs ```chunk_df.memory_usage(deep=True).sum()```
# | Metric                                   | Source | Measures                                         | Scope                           | Typical Usage                            |
# | ---------------------------------------- | ------ | ------------------------------------------------ | ------------------------------- | ---------------------------------------- |
# | `process.memory_info().rss`              | psutil | Total memory in use by the entire Python process | Global (everything in memory)   | Monitor overall memory usage             |
# | `chunk_df.memory_usage(deep=True).sum()` | pandas | Memory used by one DataFrame                     | Local (that specific DataFrame) | Estimate DataFrame size, tune chunk size |

# %% [markdown]
# #### Use the ```load_data_from_csv``` function to load the data from a csv file to the database

# %% [markdown]
# ### Load customers csv data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="customers")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "customers"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.01 MB
# current process memory usage : 180.09 MB
# df chunk 2 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 3 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 4 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 5 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 6 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 7 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 8 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 9 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 10 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 11 -> rows 50, size: 0.01 MB
# current process memory usage : 180.11 MB
# df chunk 12 -> rows 50, size: 0.01 MB
# ...

# %% [markdown]
# #### Analysis:
# As you can see I have managed to reduce the memory usage from ```memory usage: 754.1 KB``` to ```df chunk 1 -> rows 50, size: 0.01 MB```. <br>
# Now one drawback of this method is that I have to make multiple calls to the database in order to load data chunk by chunk into the table in the database in a loop. <br>
# In the method where a single dataFrame was generated I was able to insert data all in one go just in one database call.

# %% [markdown]
# ### **Load products data from the csv file into the database:**

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="products")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "products"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 18, size: 0.00 MB
# current process memory usage : 180.17 MB
# {'status': True, 'message': "\n Done loading all 18 rows into 'products'."}

# %% [markdown]
# ### Load orders csv data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="orders")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "orders"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.01 MB
# current process memory usage : 181.76 MB
# df chunk 2 -> rows 50, size: 0.01 MB
# current process memory usage : 182.20 MB
# df chunk 3 -> rows 50, size: 0.01 MB
# current process memory usage : 182.24 MB
# df chunk 4 -> rows 50, size: 0.01 MB
# current process memory usage : 182.27 MB
# df chunk 5 -> rows 50, size: 0.01 MB
# current process memory usage : 182.29 MB
# df chunk 6 -> rows 50, size: 0.01 MB
# current process memory usage : 182.32 MB
# df chunk 7 -> rows 50, size: 0.01 MB
# current process memory usage : 182.37 MB
# df chunk 8 -> rows 50, size: 0.01 MB
# current process memory usage : 182.40 MB
# df chunk 9 -> rows 50, size: 0.01 MB
# current process memory usage : 182.43 MB
# df chunk 10 -> rows 50, size: 0.01 MB
# current process memory usage : 182.45 MB
# df chunk 11 -> rows 50, size: 0.01 MB
# current process memory usage : 182.49 MB
# df chunk 12 -> rows 50, size: 0.01 MB
# ...

# %% [markdown]
# ### Load counrty_stats data into the database:

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="country_stats")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "country_stats"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.01 MB
# current process memory usage : 187.00 MB
# df chunk 2 -> rows 50, size: 0.01 MB
# current process memory usage : 187.07 MB
# df chunk 3 -> rows 50, size: 0.01 MB
# current process memory usage : 187.11 MB
# df chunk 4 -> rows 45, size: 0.01 MB
# current process memory usage : 187.17 MB
# {'status': True,
#  'message': "\n Done loading all 195 rows into 'country_stats'."}

# %% [markdown]
# ### Load happiness_scores csv data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="happiness_scores")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "happiness_scores"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.01 MB
# current process memory usage : 187.20 MB
# df chunk 2 -> rows 50, size: 0.01 MB
# current process memory usage : 187.27 MB
# df chunk 3 -> rows 50, size: 0.01 MB
# current process memory usage : 187.30 MB
# df chunk 4 -> rows 50, size: 0.01 MB
# current process memory usage : 187.34 MB
# df chunk 5 -> rows 50, size: 0.01 MB
# current process memory usage : 187.41 MB
# df chunk 6 -> rows 50, size: 0.01 MB
# current process memory usage : 187.44 MB
# df chunk 7 -> rows 50, size: 0.01 MB
# current process memory usage : 187.48 MB
# df chunk 8 -> rows 50, size: 0.01 MB
# current process memory usage : 187.53 MB
# df chunk 9 -> rows 50, size: 0.01 MB
# current process memory usage : 187.59 MB
# df chunk 10 -> rows 50, size: 0.01 MB
# current process memory usage : 187.64 MB
# df chunk 11 -> rows 50, size: 0.01 MB
# current process memory usage : 187.66 MB
# df chunk 12 -> rows 50, size: 0.01 MB
# ...

# %% [markdown]
# ### Load inflation_rates csv data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="inflation_rates")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "inflation_rates"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.00 MB
# current process memory usage : 188.33 MB
# df chunk 2 -> rows 50, size: 0.00 MB
# current process memory usage : 188.34 MB
# df chunk 3 -> rows 50, size: 0.00 MB
# current process memory usage : 188.34 MB
# df chunk 4 -> rows 39, size: 0.00 MB
# current process memory usage : 188.35 MB
# {'status': True,
#  'message': "\n Done loading all 189 rows into 'inflation_rates'."}

# %% [markdown]
# ### Load players csv data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="players")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "players"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.04 MB
# current process memory usage : 188.56 MB
# df chunk 2 -> rows 50, size: 0.04 MB
# current process memory usage : 188.85 MB
# df chunk 3 -> rows 50, size: 0.04 MB
# current process memory usage : 188.95 MB
# df chunk 4 -> rows 50, size: 0.04 MB
# current process memory usage : 189.03 MB
# df chunk 5 -> rows 50, size: 0.04 MB
# current process memory usage : 189.09 MB
# df chunk 6 -> rows 50, size: 0.04 MB
# current process memory usage : 189.18 MB
# df chunk 7 -> rows 50, size: 0.04 MB
# current process memory usage : 189.26 MB
# df chunk 8 -> rows 50, size: 0.04 MB
# current process memory usage : 189.34 MB
# df chunk 9 -> rows 50, size: 0.04 MB
# current process memory usage : 189.41 MB
# df chunk 10 -> rows 50, size: 0.04 MB
# current process memory usage : 189.50 MB
# df chunk 11 -> rows 50, size: 0.04 MB
# current process memory usage : 189.57 MB
# df chunk 12 -> rows 50, size: 0.04 MB
# ...

# %% [markdown]
# #### Load salaries csv data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="salaries")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "salaries"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.01 MB
# current process memory usage : 221.00 MB
# df chunk 2 -> rows 50, size: 0.01 MB
# current process memory usage : 221.03 MB
# df chunk 3 -> rows 50, size: 0.01 MB
# current process memory usage : 221.06 MB
# df chunk 4 -> rows 50, size: 0.01 MB
# current process memory usage : 221.07 MB
# df chunk 5 -> rows 50, size: 0.01 MB
# current process memory usage : 221.08 MB
# df chunk 6 -> rows 50, size: 0.01 MB
# current process memory usage : 221.09 MB
# df chunk 7 -> rows 50, size: 0.01 MB
# current process memory usage : 221.11 MB
# df chunk 8 -> rows 50, size: 0.01 MB
# current process memory usage : 221.12 MB
# df chunk 9 -> rows 50, size: 0.01 MB
# current process memory usage : 221.13 MB
# df chunk 10 -> rows 50, size: 0.01 MB
# current process memory usage : 221.16 MB
# df chunk 11 -> rows 50, size: 0.01 MB
# current process memory usage : 221.18 MB
# df chunk 12 -> rows 50, size: 0.01 MB
# ...

# %% [markdown]
# ### Load school_details csv file data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="school_details")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "school_details"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.01 MB
# current process memory usage : 228.92 MB
# df chunk 2 -> rows 50, size: 0.01 MB
# current process memory usage : 229.52 MB
# df chunk 3 -> rows 50, size: 0.01 MB
# current process memory usage : 229.55 MB
# df chunk 4 -> rows 50, size: 0.01 MB
# current process memory usage : 229.57 MB
# df chunk 5 -> rows 50, size: 0.01 MB
# current process memory usage : 229.60 MB
# df chunk 6 -> rows 50, size: 0.01 MB
# current process memory usage : 229.61 MB
# df chunk 7 -> rows 50, size: 0.01 MB
# current process memory usage : 229.64 MB
# df chunk 8 -> rows 50, size: 0.01 MB
# current process memory usage : 229.66 MB
# df chunk 9 -> rows 50, size: 0.01 MB
# current process memory usage : 229.68 MB
# df chunk 10 -> rows 50, size: 0.01 MB
# current process memory usage : 229.71 MB
# df chunk 11 -> rows 50, size: 0.01 MB
# current process memory usage : 229.73 MB
# df chunk 12 -> rows 50, size: 0.01 MB
# ...

# %% [markdown]
# ### Load schools csv data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="schools")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "schools"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.01 MB
# current process memory usage : 230.09 MB
# df chunk 2 -> rows 50, size: 0.01 MB
# current process memory usage : 230.11 MB
# df chunk 3 -> rows 50, size: 0.01 MB
# current process memory usage : 230.12 MB
# df chunk 4 -> rows 50, size: 0.01 MB
# current process memory usage : 230.13 MB
# df chunk 5 -> rows 50, size: 0.01 MB
# current process memory usage : 230.16 MB
# df chunk 6 -> rows 50, size: 0.01 MB
# current process memory usage : 230.17 MB
# df chunk 7 -> rows 50, size: 0.01 MB
# current process memory usage : 230.18 MB
# df chunk 8 -> rows 50, size: 0.01 MB
# current process memory usage : 230.21 MB
# df chunk 9 -> rows 50, size: 0.01 MB
# current process memory usage : 230.24 MB
# df chunk 10 -> rows 50, size: 0.01 MB
# current process memory usage : 230.26 MB
# df chunk 11 -> rows 50, size: 0.01 MB
# current process memory usage : 230.27 MB
# df chunk 12 -> rows 50, size: 0.01 MB
# ...

# %% [markdown]
# #### Load student_grades csv data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="student_grades")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "student_grades"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 50, size: 0.01 MB
# current process memory usage : 231.76 MB
# df chunk 2 -> rows 14, size: 0.00 MB
# current process memory usage : 231.76 MB
# {'status': True,
#  'message': "\n Done loading all 64 rows into 'student_grades'."}

# %% [markdown]
# ### Load students csv data into the database

# %%
csv_file_path_model = CsvFilePathModel(csv_file_name="students")
csv_file_path_str = get_csv_file_path(csv_file_path_model)
table_name = "students"
if_exists = "append"
index = False
engine = engine_obj
load_data_from_csv_model = WriteDataToDBFromCSVModel(table_name=table_name,if_exists=if_exists,index=index,engine=engine,csv_file_path=csv_file_path_str)
load_data_from_csv(load_data_from_csv_model)
# Out:
# Running on Linux
# df chunk 1 -> rows 17, size: 0.00 MB
# current process memory usage : 229.93 MB
# {'status': True, 'message': "\n Done loading all 17 rows into 'students'."}

# %% [markdown]
# ## Now that all the required data has been loaded from the csv files we can move forward.

# %% [markdown]
# ## Read a Table from the database table

# %% [markdown]
# ### Method 1 : Read data using raw sql queries
# In this method I will have to write a function

# %% [markdown]
# ### Select query where data is ordered in descending order and the number of rows returned must be 20

# %%
select_query_string = """
SELECT * FROM students ORDER BY id DESC LIMIT 10;
"""

exec_query = ExecQueryModel(engine=engine_obj, query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>17</td><td>Noah Scott</td><td>12</td><td>3.3000</td><td>False</td><td>None</td><td>noah.scott@mavenhighschool.com</td></tr><tr><td>2</td><td>16</td><td>Peter Park</td><td>12</td><td>2.9000</td><td>True</td><td>None</td><td>peter.park@mavenhighschool.com</td></tr><tr><td>3</td><td>15</td><td>Olivia Adams</td><td>9</td><td>3.7000</td><td>True</td><td>None</td><td>olivia.adams@mavenhighschool.edu</td></tr><tr><td>4</td><td>14</td><td>Noah Scott</td><td>12</td><td>3.3000</td><td>False</td><td>None</td><td>noah.scott@mavenparkdistrict.com</td></tr><tr><td>5</td><td>13</td><td>Mia Harris</td><td>11</td><td>3.0000</td><td>False</td><td>None</td><td>mia.harris@mavenhighschool.com</td></tr><tr><td>6</td><td>12</td><td>Liam Green</td><td>10</td><td>4.0000</td><td>True</td><td>None</td><td
# ...

# %% [markdown]
# ### Covering the Big 6 :
# - ```SELECT``` -> This tells the database what columns or calculations you want to include in the final result
# - ```FROM``` -> This tells which table to pull data from
# - ```WHERE``` -> This filters the rows before grouping or aggregating. Only rows that meet the condition will be included in the rest of the query.
# - ```GROUP BY``` -> This groups the remaining rows based on the columns you specify, so you can apply aggregate functions (like ```AVG```, ```SUM```,```COUNT```) to each group.
# - ```HAVING``` -> This filters the groups (not individual rows) after aggregation. It works like ```WHERE```, but it applies to grouped data.
# - ```ODER BY``` -> This sorts the final result by the columns(s) you choose.

# %%
select_query_string = """
SELECT grade_level, AVG(gpa) AS avg_gpa
FROM students
WHERE school_lunch = true
GROUP BY grade_level
HAVING AVG(gpa) < 3.3
ORDER BY grade_level;
"""

exec_query = ExecQueryModel(engine=engine_obj, query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>grade_level</th><th>avg_gpa</th></tr><tr><td>1</td><td>11</td><td>2.9000000000000000</td></tr><tr><td>2</td><td>12</td><td>3.1666666666666667</td></tr></table>
# {'status': True}

# %% [markdown]
# ### Common sql keywords in SELECT clause

# %% [markdown]
# #### Distinct
# Distinct returns unique values from the table.

# %%
select_query_string = """
SELECT DISTINCT grade_level FROM students;
"""

exec_query = ExecQueryModel(engine=engine_obj, query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>grade_level</th></tr><tr><td>1</td><td>10</td></tr><tr><td>2</td><td>11</td></tr><tr><td>3</td><td>9</td></tr><tr><td>4</td><td>12</td></tr></table>
# {'status': True}

# %% [markdown]
# #### Using COUNT in conjunction with DISTINCT
# Here count is one of the 5 aggregade function

# %%
select_query_string = """
SELECT COUNT(DISTINCT grade_level) FROM students;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>count</th></tr><tr><td>1</td><td>4</td></tr></table>
# {'status': True}

# %% [markdown]
# ### Max
# This returns the maximum value from the database

# %%
select_query_string = """
SELECT MAX(gpa) AS max_gpa FROM students;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>max_gpa</th></tr><tr><td>1</td><td>4.0000</td></tr></table>
# {'status': True}

# %% [markdown]
# #### Min
# This returns the minimum value from the database

# %%
select_query_string = """
SELECT MIN(gpa) As min_gpa FROM students;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>min_gpa</th></tr><tr><td>1</td><td>2.7000</td></tr></table>
# {'status': True}

# %% [markdown]
# #### Executing math operators in sql using python

# %% [markdown]
# **Subtraction**

# %%
select_query_string = """
SELECT MAX(gpa) - MIN(gpa) AS gpa_range FROM students;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>gpa_range</th></tr><tr><td>1</td><td>1.3000</td></tr></table>
# {'status': True}

# %% [markdown]
# **Addition**

# %%
select_query_string = """
SELECT MAX(gpa) + MIN(gpa) As gpa_range FROM students;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>gpa_range</th></tr><tr><td>1</td><td>6.7000</td></tr></table>
# {'status': True}

# %% [markdown]
# **Multiplication**

# %%
select_query_string = """
SELECT MAX(gpa) * MIN(gpa) AS gpa_range FROM students;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>gpa_range</th></tr><tr><td>1</td><td>10.80000000</td></tr></table>
# {'status': True}

# %% [markdown]
# **Division**

# %%
select_query_string="""
SELECT MAX(gpa) / MIN(gpa) AS gpa_range FROM students;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>gpa_range</th></tr><tr><td>1</td><td>1.4814814814814815</td></tr></table>
# {'status': True}

# %% [markdown]
# **Modulus**

# %%
select_query_string="""
SELECT MAX(gpa) % MIN(gpa) AS gpa_range FROM students;
"""

exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>gpa_range</th></tr><tr><td>1</td><td>1.3000</td></tr></table>
# {'status': True}

# %% [markdown]
# ### Common sql keywords in WHERE clause

# %% [markdown]
# #### Conditions in the WHERE clause

# %% [markdown]
# **Comparision operator (<)**

# %%
select_query_string = """
SELECT * FROM students WHERE grade_level < 12 AND school_lunch = true;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>1</td><td>Abby Johnson</td><td>10</td><td>3.1000</td><td>True</td><td>None</td><td>abby.johnson@mavenhighschool.com</td></tr><tr><td>2</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>3</td><td>8</td><td>Henry Taylor</td><td>9</td><td>3.0000</td><td>True</td><td>None</td><td>None</td></tr><tr><td>4</td><td>9</td><td>Isabella Moore</td><td>10</td><td>2.8000</td><td>True</td><td>None</td><td>isabella.moore@mavenhighschool.com</td></tr><tr><td>5</td><td>10</td><td>Jack Thompson</td><td>11</td><td>2.9000</td><td>True</td><td>None</td><td>jack.thompson@mavenhighschool.com</td></tr><tr><td>6</td><td>12</td><td>Liam Green</td><td>10</td><td>4.0000</td><td>True</td><td>None</td><td>liam.green@mave
# ...

# %% [markdown]
# **Comparision operator (>)**

# %%
select_query_string = """
SELECT * FROM students WHERE grade_level > 12 AND school_lunch = true;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# {'status': False, 'error': 'no data found!'}

# %% [markdown]
# **Comparision operator (!=)**

# %%
select_query_string = """
SELECT * FROM students WHERE grade_level != 12 AND school_lunch = true;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>1</td><td>Abby Johnson</td><td>10</td><td>3.1000</td><td>True</td><td>None</td><td>abby.johnson@mavenhighschool.com</td></tr><tr><td>2</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>3</td><td>8</td><td>Henry Taylor</td><td>9</td><td>3.0000</td><td>True</td><td>None</td><td>None</td></tr><tr><td>4</td><td>9</td><td>Isabella Moore</td><td>10</td><td>2.8000</td><td>True</td><td>None</td><td>isabella.moore@mavenhighschool.com</td></tr><tr><td>5</td><td>10</td><td>Jack Thompson</td><td>11</td><td>2.9000</td><td>True</td><td>None</td><td>jack.thompson@mavenhighschool.com</td></tr><tr><td>6</td><td>12</td><td>Liam Green</td><td>10</td><td>4.0000</td><td>True</td><td>None</td><td>liam.green@mave
# ...

# %% [markdown]
# **Comparision operator (<>)**

# %%
select_query_string = """
SELECT * FROM students WHERE grade_level <> 12 AND school_lunch = true;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>1</td><td>Abby Johnson</td><td>10</td><td>3.1000</td><td>True</td><td>None</td><td>abby.johnson@mavenhighschool.com</td></tr><tr><td>2</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>3</td><td>8</td><td>Henry Taylor</td><td>9</td><td>3.0000</td><td>True</td><td>None</td><td>None</td></tr><tr><td>4</td><td>9</td><td>Isabella Moore</td><td>10</td><td>2.8000</td><td>True</td><td>None</td><td>isabella.moore@mavenhighschool.com</td></tr><tr><td>5</td><td>10</td><td>Jack Thompson</td><td>11</td><td>2.9000</td><td>True</td><td>None</td><td>jack.thompson@mavenhighschool.com</td></tr><tr><td>6</td><td>12</td><td>Liam Green</td><td>10</td><td>4.0000</td><td>True</td><td>None</td><td>liam.green@mave
# ...

# %% [markdown]
# **Comparision operator (<=)**

# %%
select_query_string = """
SELECT * FROM students WHERE grade_level <= 12 AND school_lunch = true;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>1</td><td>Abby Johnson</td><td>10</td><td>3.1000</td><td>True</td><td>None</td><td>abby.johnson@mavenhighschool.com</td></tr><tr><td>2</td><td>3</td><td>Catherine Davis</td><td>12</td><td>3.6000</td><td>True</td><td>None</td><td>catherine.davis@mavenhighschool.com</td></tr><tr><td>3</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>4</td><td>7</td><td>Grace Lee</td><td>12</td><td>3.0000</td><td>True</td><td>None</td><td>grace.lee@mavenhighschool.com</td></tr><tr><td>5</td><td>8</td><td>Henry Taylor</td><td>9</td><td>3.0000</td><td>True</td><td>None</td><td>None</td></tr><tr><td>6</td><td>9</td><td>Isabella Moore</td><td>10</td><td>2.8000</td><td>True</td><td>None</td><td>isabella.moore@mave
# ...

# %% [markdown]
# **Comparision operator (>=)**

# %%
select_query_string = """
SELECT * FROM students WHERE grade_level >= 12 AND school_lunch = true;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>3</td><td>Catherine Davis</td><td>12</td><td>3.6000</td><td>True</td><td>None</td><td>catherine.davis@mavenhighschool.com</td></tr><tr><td>2</td><td>7</td><td>Grace Lee</td><td>12</td><td>3.0000</td><td>True</td><td>None</td><td>grace.lee@mavenhighschool.com</td></tr><tr><td>3</td><td>16</td><td>Peter Park</td><td>12</td><td>2.9000</td><td>True</td><td>None</td><td>peter.park@mavenhighschool.com</td></tr></table>
# {'status': True}

# %% [markdown]
# **Comparision operator (=)**

# %%
select_query_string = """
SELECT * FROM students WHERE grade_level = 12 AND school_lunch = true;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>3</td><td>Catherine Davis</td><td>12</td><td>3.6000</td><td>True</td><td>None</td><td>catherine.davis@mavenhighschool.com</td></tr><tr><td>2</td><td>7</td><td>Grace Lee</td><td>12</td><td>3.0000</td><td>True</td><td>None</td><td>grace.lee@mavenhighschool.com</td></tr><tr><td>3</td><td>16</td><td>Peter Park</td><td>12</td><td>2.9000</td><td>True</td><td>None</td><td>peter.park@mavenhighschool.com</td></tr></table>
# {'status': True}

# %% [markdown]
# #### LIKE operator with WHERE clause
# - ```LIKE``` -> It is used to look up for string that is either closely or exactly matches with the the string from the database.

# %%
select_query_string = """
SELECT * FROM students WHERE email LIKE '%.edu';
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>2</td><td>11</td><td>Karen White</td><td>9</td><td>3.4000</td><td>False</td><td>None</td><td>karen.white@mavenhighschool.edu</td></tr><tr><td>3</td><td>15</td><td>Olivia Adams</td><td>9</td><td>3.7000</td><td>True</td><td>None</td><td>olivia.adams@mavenhighschool.edu</td></tr></table>
# {'status': True}

# %%
select_query_string = """
SELECT * FROM students WHERE email LIKE 'bob.%';
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>2</td><td>Bob Smith</td><td>11</td><td>3.1000</td><td>False</td><td>None</td><td>bob.smith@mavenhighschool.com</td></tr></table>
# {'status': True}

# %%
select_query_string = """
SELECT * FROM students WHERE email LIKE '%noah%';
"""
exec_query = ExecQueryModel(engine=engine_obj,query=select_query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>14</td><td>Noah Scott</td><td>12</td><td>3.3000</td><td>False</td><td>None</td><td>noah.scott@mavenparkdistrict.com</td></tr><tr><td>2</td><td>17</td><td>Noah Scott</td><td>12</td><td>3.3000</td><td>False</td><td>None</td><td>noah.scott@mavenhighschool.com</td></tr></table>
# {'status': True}

# %% [markdown]
# ### Common sql keywords which are not found in SELECT or WHERE clause

# %% [markdown]
# #### ASC and DESC keywords

# %% [markdown]
# **ASC** : Order by ascending order

# %%
query_string = """
SELECT * FROM students WHERE email LIKE '%.com' ORDER BY gpa ASC;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>5</td><td>Eva Martinez</td><td>10</td><td>2.7000</td><td>False</td><td>None</td><td>eva.martinez@mavenhighschool.com</td></tr><tr><td>2</td><td>9</td><td>Isabella Moore</td><td>10</td><td>2.8000</td><td>True</td><td>None</td><td>isabella.moore@mavenhighschool.com</td></tr><tr><td>3</td><td>10</td><td>Jack Thompson</td><td>11</td><td>2.9000</td><td>True</td><td>None</td><td>jack.thompson@mavenhighschool.com</td></tr><tr><td>4</td><td>16</td><td>Peter Park</td><td>12</td><td>2.9000</td><td>True</td><td>None</td><td>peter.park@mavenhighschool.com</td></tr><tr><td>5</td><td>13</td><td>Mia Harris</td><td>11</td><td>3.0000</td><td>False</td><td>None</td><td>mia.harris@mavenhighschool.com</td></tr><tr><td>6</td><td>7</td><td>Grace Lee</td><td>12</td><td>3.0000</td><td>True</td><td>None
# ...

# %% [markdown]
# **DESC** : Order by descending order

# %%
query_string = """
SELECT * FROM students WHERE email LIKE '%.com' ORDER BY gpa DESC;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>12</td><td>Liam Green</td><td>10</td><td>4.0000</td><td>True</td><td>None</td><td>liam.green@mavenhighschool.com</td></tr><tr><td>2</td><td>3</td><td>Catherine Davis</td><td>12</td><td>3.6000</td><td>True</td><td>None</td><td>catherine.davis@mavenhighschool.com</td></tr><tr><td>3</td><td>14</td><td>Noah Scott</td><td>12</td><td>3.3000</td><td>False</td><td>None</td><td>noah.scott@mavenparkdistrict.com</td></tr><tr><td>4</td><td>17</td><td>Noah Scott</td><td>12</td><td>3.3000</td><td>False</td><td>None</td><td>noah.scott@mavenhighschool.com</td></tr><tr><td>5</td><td>6</td><td>Frank Wilson</td><td>11</td><td>3.2000</td><td>False</td><td>None</td><td>frank.wilson@mavenhighschool.com</td></tr><tr><td>6</td><td>1</td><td>Abby Johnson</td><td>10</td><td>3.1000</td><td>True</td><td>No
# ...

# %% [markdown]
# #### LIMIT
# This keyword is used to limit the number of rows that you get using the SELECT clause

# %%
query_string = """
SELECT * FROM students LIMIT 5 ;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>1</td><td>Abby Johnson</td><td>10</td><td>3.1000</td><td>True</td><td>None</td><td>abby.johnson@mavenhighschool.com</td></tr><tr><td>2</td><td>2</td><td>Bob Smith</td><td>11</td><td>3.1000</td><td>False</td><td>None</td><td>bob.smith@mavenhighschool.com</td></tr><tr><td>3</td><td>3</td><td>Catherine Davis</td><td>12</td><td>3.6000</td><td>True</td><td>None</td><td>catherine.davis@mavenhighschool.com</td></tr><tr><td>4</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>5</td><td>5</td><td>Eva Martinez</td><td>10</td><td>2.7000</td><td>False</td><td>None</td><td>eva.martinez@mavenhighschool.com</td></tr></table>
# {'status': True}

# %% [markdown]
# **Using LIMIT keyword along with the ORDER BY**

# %%
query_string = """
SELECT * FROM students ORDER BY gpa DESC LIMIT 5;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>12</td><td>Liam Green</td><td>10</td><td>4.0000</td><td>True</td><td>None</td><td>liam.green@mavenhighschool.com</td></tr><tr><td>2</td><td>15</td><td>Olivia Adams</td><td>9</td><td>3.7000</td><td>True</td><td>None</td><td>olivia.adams@mavenhighschool.edu</td></tr><tr><td>3</td><td>3</td><td>Catherine Davis</td><td>12</td><td>3.6000</td><td>True</td><td>None</td><td>catherine.davis@mavenhighschool.com</td></tr><tr><td>4</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>5</td><td>11</td><td>Karen White</td><td>9</td><td>3.4000</td><td>False</td><td>None</td><td>karen.white@mavenhighschool.edu</td></tr></table>
# {'status': True}

# %% [markdown]
# ### Common sql keywords CASE statements
# ```CASE``` statements allow us to carry out conditional logic similar to an if else statement.

# %%
query_string = """
SELECT student_name, grade_level, CASE 
WHEN grade_level = 9 THEN 'Freshmen'
WHEN grade_level = 10 THEN 'Sophomore'
WHEN grade_level = 11 THEN 'Junior'
ELSE 'Senior' END AS student_class FROM students;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>student_name</th><th>grade_level</th><th>student_class</th></tr><tr><td>1</td><td>Abby Johnson</td><td>10</td><td>Sophomore</td></tr><tr><td>2</td><td>Bob Smith</td><td>11</td><td>Junior</td></tr><tr><td>3</td><td>Catherine Davis</td><td>12</td><td>Senior</td></tr><tr><td>4</td><td>Daniel Brown</td><td>9</td><td>Freshmen</td></tr><tr><td>5</td><td>Eva Martinez</td><td>10</td><td>Sophomore</td></tr><tr><td>6</td><td>Frank Wilson</td><td>11</td><td>Junior</td></tr><tr><td>7</td><td>Grace Lee</td><td>12</td><td>Senior</td></tr><tr><td>8</td><td>Henry Taylor</td><td>9</td><td>Freshmen</td></tr><tr><td>9</td><td>Isabella Moore</td><td>10</td><td>Sophomore</td></tr><tr><td>10</td><td>Jack Thompson</td><td>11</td><td>Junior</td></tr><tr><td>11</td><td>Karen White</td><td>9</td><td>Freshmen</td></tr><tr><td>12</td><td>Liam Green</td><td>10</td><td>Sophomore</td></tr><tr><td>13</td><td>Mia Harris</td><td>11</td><td>Juni
# ...

# %% [markdown]
# ## Practice Section 1 :

# %%
query_string = """
SELECT grade_level, AVG(gpa) AS avg_gpa
FROM students
WHERE school_lunch = true
GROUP BY grade_level
HAVING AVG(gpa) < 3.3
ORDER BY grade_level DESC;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>grade_level</th><th>avg_gpa</th></tr><tr><td>1</td><td>12</td><td>3.1666666666666667</td></tr><tr><td>2</td><td>11</td><td>2.9000000000000000</td></tr></table>
# {'status': True}

# %% [markdown]
# ### Count the number of distinct grade_level in the table

# %%
query_string = """
SELECT COUNT(DISTINCT grade_level) FROM students;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>count</th></tr><tr><td>1</td><td>4</td></tr></table>
# {'status': True}

# %% [markdown]
# ### Get the students from 9th and 11th grades only using the IN operator

# %%
query_string = """
SELECT * FROM students WHERE grade_level IN (9,11);
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>2</td><td>Bob Smith</td><td>11</td><td>3.1000</td><td>False</td><td>None</td><td>bob.smith@mavenhighschool.com</td></tr><tr><td>2</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>3</td><td>6</td><td>Frank Wilson</td><td>11</td><td>3.2000</td><td>False</td><td>None</td><td>frank.wilson@mavenhighschool.com</td></tr><tr><td>4</td><td>8</td><td>Henry Taylor</td><td>9</td><td>3.0000</td><td>True</td><td>None</td><td>None</td></tr><tr><td>5</td><td>10</td><td>Jack Thompson</td><td>11</td><td>2.9000</td><td>True</td><td>None</td><td>jack.thompson@mavenhighschool.com</td></tr><tr><td>6</td><td>11</td><td>Karen White</td><td>9</td><td>3.4000</td><td>False</td><td>None</td><td>karen.white@mavenhighs
# ...

# %% [markdown]
# ### Filter out rows that have null values in them

# %% [markdown]
# Here I am going to filter out rows that have email

# %%
query_string = """
SELECT * FROM students WHERE email is NULL;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>8</td><td>Henry Taylor</td><td>9</td><td>3.0000</td><td>True</td><td>None</td><td>None</td></tr></table>
# {'status': True}

# %% [markdown]
# In addition to that I can also run is NOT NULL

# %%
query_string = """
SELECT * FROM students WHERE email is NOT NULL;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>1</td><td>Abby Johnson</td><td>10</td><td>3.1000</td><td>True</td><td>None</td><td>abby.johnson@mavenhighschool.com</td></tr><tr><td>2</td><td>2</td><td>Bob Smith</td><td>11</td><td>3.1000</td><td>False</td><td>None</td><td>bob.smith@mavenhighschool.com</td></tr><tr><td>3</td><td>3</td><td>Catherine Davis</td><td>12</td><td>3.6000</td><td>True</td><td>None</td><td>catherine.davis@mavenhighschool.com</td></tr><tr><td>4</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>5</td><td>5</td><td>Eva Martinez</td><td>10</td><td>2.7000</td><td>False</td><td>None</td><td>eva.martinez@mavenhighschool.com</td></tr><tr><td>6</td><td>6</td><td>Frank Wilson</td><td>11</td><td>3.2000</td><td>False</td><td>No
# ...

# %% [markdown]
# ### Filter out students that have emails that ends with ```edu```

# %%
query_string = """
SELECT * FROM students WHERE email LIKE '%.edu' ORDER BY student_name ASC;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>2</td><td>11</td><td>Karen White</td><td>9</td><td>3.4000</td><td>False</td><td>None</td><td>karen.white@mavenhighschool.edu</td></tr><tr><td>3</td><td>15</td><td>Olivia Adams</td><td>9</td><td>3.7000</td><td>True</td><td>None</td><td>olivia.adams@mavenhighschool.edu</td></tr></table>
# {'status': True}

# %% [markdown]
# ### Only show first 7 rows from the table (using LIMIT)

# %%
query_string = """
SELECT * FROM students LIMIT 7;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>grade_level</th><th>gpa</th><th>school_lunch</th><th>birthday</th><th>email</th></tr><tr><td>1</td><td>1</td><td>Abby Johnson</td><td>10</td><td>3.1000</td><td>True</td><td>None</td><td>abby.johnson@mavenhighschool.com</td></tr><tr><td>2</td><td>2</td><td>Bob Smith</td><td>11</td><td>3.1000</td><td>False</td><td>None</td><td>bob.smith@mavenhighschool.com</td></tr><tr><td>3</td><td>3</td><td>Catherine Davis</td><td>12</td><td>3.6000</td><td>True</td><td>None</td><td>catherine.davis@mavenhighschool.com</td></tr><tr><td>4</td><td>4</td><td>Daniel Brown</td><td>9</td><td>3.5000</td><td>True</td><td>None</td><td>daniel.brown@mavenhighschool.edu</td></tr><tr><td>5</td><td>5</td><td>Eva Martinez</td><td>10</td><td>2.7000</td><td>False</td><td>None</td><td>eva.martinez@mavenhighschool.com</td></tr><tr><td>6</td><td>6</td><td>Frank Wilson</td><td>11</td><td>3.2000</td><td>False</td><td>No
# ...

# %% [markdown]
# ### Use CASE clause to assign flags based on grade_level

# %%
query_string = """
SELECT id,student_name,gpa,grade_level, CASE
WHEN grade_level = 9 THEN 'Freshmen'
WHEN grade_level = 10 THEN 'Sophomore'
WHEN grade_level = 11 THEN 'Junior'
ELSE 'Senior' END AS student_tier
FROM students WHERE school_lunch = false;
"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>id</th><th>student_name</th><th>gpa</th><th>grade_level</th><th>student_tier</th></tr><tr><td>1</td><td>2</td><td>Bob Smith</td><td>3.1000</td><td>11</td><td>Junior</td></tr><tr><td>2</td><td>5</td><td>Eva Martinez</td><td>2.7000</td><td>10</td><td>Sophomore</td></tr><tr><td>3</td><td>6</td><td>Frank Wilson</td><td>3.2000</td><td>11</td><td>Junior</td></tr><tr><td>4</td><td>11</td><td>Karen White</td><td>3.4000</td><td>9</td><td>Freshmen</td></tr><tr><td>5</td><td>13</td><td>Mia Harris</td><td>3.0000</td><td>11</td><td>Junior</td></tr><tr><td>6</td><td>14</td><td>Noah Scott</td><td>3.3000</td><td>12</td><td>Senior</td></tr><tr><td>7</td><td>17</td><td>Noah Scott</td><td>3.3000</td><td>12</td><td>Senior</td></tr></table>
# {'status': True}

# %% [markdown]
# ## Multi-Table Analysis

# %% [markdown]
# Lets say I have a ```happyness_scores``` and ```country_stats``` table, Lets say I want a single output that had details about each country.
# - I want to show the ```happyness_score``` column from the ```happyness_scores``` table and from the ```country_stats``` table I want to show ```country``` , ```continent``` and ```population```.
# <br>
# In that case I will have to combine these two tables. In sql there two ways to combine these two tables.
# - ```JOIN``` adds related columns from one table to another, based on common columns.
# - ```UNION``` stacks the rows from multiple tables with the same column structure.

# %% [markdown]
# ### BASIC JOINS
# Use ```JOIN``` to combine two tables based on common values in a columns.
# - The tables must have at least one column with matching values.
# - Basic ```JOINS``` options includes ```INNER```, ```LEFT```, ```RIGHT```, ```FULL```, ```OUTER```

# %%
query_string = """

"""
exec_query = ExecQueryModel(engine=engine_obj,query=query_string)
exec_sql_query_fun(exec_query)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>customer_id</th><th>city</th><th>state_province</th><th>country</th><th>region</th></tr><tr><td>1</td><td>39278</td><td>Naperville</td><td>Illinois</td><td>United States</td><td>Interior</td></tr><tr><td>2</td><td>21102</td><td>Henderson</td><td>Kentucky</td><td>United States</td><td>Gulf</td></tr><tr><td>3</td><td>21240</td><td>Los Angeles</td><td>California</td><td>United States</td><td>Pacific</td></tr><tr><td>4</td><td>32368</td><td>Huntsville</td><td>Texas</td><td>United States</td><td>Interior</td></tr><tr><td>5</td><td>25832</td><td>Laredo</td><td>Texas</td><td>United States</td><td>Interior</td></tr><tr><td>6</td><td>39448</td><td>Springfield</td><td>Virginia</td><td>United States</td><td>Gulf</td></tr><tr><td>7</td><td>11050</td><td>San Francisco</td><td>California</td><td>United States</td><td>Pacific</td></tr><tr><td>8</td><td>16678</td><td>Bossier City</td><td>Louisiana</td><td>United States</td><td
# ...

# %% [markdown]
# ### Method 2 : Read data using a common function
# In this case I have created a common function that accepts :
#
# <br>
#
# - Table name
# - column_name list
# - database_engine object
# - max_rows
#
# <br>
#
# and it then fetches the data from the database and then renders a table.
#
# ### Create a function to read data from the database using
# #### Explaination :
# ```python
# model_config = {
#         "arbitrary_types_allowed":True
#     }
# ```
#
# <br>
#
# - The reason I have to use ```model_config``` to set ```arbitrary_types_allowed``` flag to ```True``` to avoid error raiseed by pydantic saying ```RuntimeError: Unable to validate field "engine"```
# - This tells pydantic to accept the object as it is and don't be alarmed by just accept it as it is.

# %%
# Created a pydantic model.
# This model is used to validate the parameters required to read the data from a table from the database
class ReadDbTableModel(BaseModel):
    table_name:str=Field(default=None)
    columns:List[str]=Field(default=[])
    engine:Engine
    max_rows : Optional[int] = Field(default=20)
    model_config = {
        "arbitrary_types_allowed":True
    }
    
# Create a function to read the data from the table in the database
def read_db_table_data(table_model_config:ReadDbTableModel) -> tuple[list[str], list[tuple[Any,...]]]:
    try:
        with table_model_config.engine.connect() as conn:
            if table_model_config.columns:
                query = text(f"SELECT {', '.join(table_model_config.columns)} FROM {table_model_config.table_name} LIMIT {table_model_config.max_rows}")
            else:
                query = text(f"SELECT * FROM {table_model_config.table_name} LIMIT {table_model_config.max_rows}")
            result = conn.execute(query)
            rows_data = result.fetchall()
            headers_data = result.keys()
        return headers_data,rows_data
    except Exception as e:
        raise RuntimeError(f"Cannot read the data from the table {table_model_config.table_name} : {e}")

# %% [markdown]
# ### NOTICE :
# If you are using passord type field in your pydantic model then using SecretStr is not a good idea in this case. Since we want to make connection to the database we have to use str instead to be able to successfully make a connection to the database otherwise we will get the error : "Authentication failed unable login into postgres"

# %% [markdown]
# ### Get all the columns from the table

# %%
config_read_customers_table = ReadDbTableModel(table_name="customers", engine=engine_obj)
headers_data, rows_data = read_db_table_data(config_read_customers_table)
display_obj = DisplayDataModel(headers=headers_data, rows=rows_data)
display_data(display_obj)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>customer_id</th><th>city</th><th>state_province</th><th>country</th><th>region</th></tr><tr><td>1</td><td>39278</td><td>Naperville</td><td>Illinois</td><td>United States</td><td>Interior</td></tr><tr><td>2</td><td>21102</td><td>Henderson</td><td>Kentucky</td><td>United States</td><td>Gulf</td></tr><tr><td>3</td><td>21240</td><td>Los Angeles</td><td>California</td><td>United States</td><td>Pacific</td></tr><tr><td>4</td><td>32368</td><td>Huntsville</td><td>Texas</td><td>United States</td><td>Interior</td></tr><tr><td>5</td><td>25832</td><td>Laredo</td><td>Texas</td><td>United States</td><td>Interior</td></tr><tr><td>6</td><td>39448</td><td>Springfield</td><td>Virginia</td><td>United States</td><td>Gulf</td></tr><tr><td>7</td><td>11050</td><td>San Francisco</td><td>California</td><td>United States</td><td>Pacific</td></tr><tr><td>8</td><td>16678</td><td>Bossier City</td><td>Louisiana</td><td>United States</td><td
# ...

# %% [markdown]
# ### Get selected columns from the table

# %%
config_read_customers_table = ReadDbTableModel(table_name="customers", engine=engine_obj
                                               ,columns=["city","state_province"])
headers_data, rows_data = read_db_table_data(config_read_customers_table)
display_obj = DisplayDataModel(headers=headers_data, rows=rows_data)
display_data(display_obj)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>city</th><th>state_province</th></tr><tr><td>1</td><td>Naperville</td><td>Illinois</td></tr><tr><td>2</td><td>Henderson</td><td>Kentucky</td></tr><tr><td>3</td><td>Los Angeles</td><td>California</td></tr><tr><td>4</td><td>Huntsville</td><td>Texas</td></tr><tr><td>5</td><td>Laredo</td><td>Texas</td></tr><tr><td>6</td><td>Springfield</td><td>Virginia</td></tr><tr><td>7</td><td>San Francisco</td><td>California</td></tr><tr><td>8</td><td>Bossier City</td><td>Louisiana</td></tr><tr><td>9</td><td>Mount Pleasant</td><td>South Carolina</td></tr><tr><td>10</td><td>Newark</td><td>Ohio</td></tr><tr><td>11</td><td>Philadelphia</td><td>Pennsylvania</td></tr><tr><td>12</td><td>Roswell</td><td>Georgia</td></tr><tr><td>13</td><td>Philadelphia</td><td>Pennsylvania</td></tr><tr><td>14</td><td>Scottsdale</td><td>Arizona</td></tr><tr><td>15</td><td>Miami</td><td>Florida</td></tr><tr><td>16</td><td>Las Vegas</td><td>Nevada</td></tr
# ...

# %% [markdown]
# ### Get data of 80 rows from the table

# %%
config_read_customers_table = ReadDbTableModel(table_name="customers", engine=engine_obj
                                               ,columns=["city","state_province"], max_rows=80)
headers_data, rows_data = read_db_table_data(config_read_customers_table)
display_obj = DisplayDataModel(headers=headers_data, rows=rows_data, max_rows=80)
display_data(display_obj)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>city</th><th>state_province</th></tr><tr><td>1</td><td>Naperville</td><td>Illinois</td></tr><tr><td>2</td><td>Henderson</td><td>Kentucky</td></tr><tr><td>3</td><td>Los Angeles</td><td>California</td></tr><tr><td>4</td><td>Huntsville</td><td>Texas</td></tr><tr><td>5</td><td>Laredo</td><td>Texas</td></tr><tr><td>6</td><td>Springfield</td><td>Virginia</td></tr><tr><td>7</td><td>San Francisco</td><td>California</td></tr><tr><td>8</td><td>Bossier City</td><td>Louisiana</td></tr><tr><td>9</td><td>Mount Pleasant</td><td>South Carolina</td></tr><tr><td>10</td><td>Newark</td><td>Ohio</td></tr><tr><td>11</td><td>Philadelphia</td><td>Pennsylvania</td></tr><tr><td>12</td><td>Roswell</td><td>Georgia</td></tr><tr><td>13</td><td>Philadelphia</td><td>Pennsylvania</td></tr><tr><td>14</td><td>Scottsdale</td><td>Arizona</td></tr><tr><td>15</td><td>Miami</td><td>Florida</td></tr><tr><td>16</td><td>Las Vegas</td><td>Nevada</td></tr
# ...

# %% [markdown]
# ## Unable to save changes in the jupyter notebook file

# %% [markdown]
# **NOTICE:** This error happens only on windows I haven't faced this type of error before on any of the linux systems I have been using jupyter notebook on a daily basis on my personal pc with arch linux installed on it. I will have to look into it more thouroughly as to why this error is happening.
#
# I randomely faced an issue where I was not able to save any changes I made in my jupyter notebook. <br>
#
# Error message looks something like this : <br>
# ```Unexpected error while saving file: python/database_operation/Database_operations_python.ipynb [Errno 22] Invalid argument: 'D:\\training\\credencys-training-pyspark\\python\\database_operation\\Database_operations_python.ipynb'```
#
# <br>
#
# I googled about this issue and found out :
# - I found out that windows doesn't allow you to make changes to a file if another program is using it. In my case this was irrelevant because only jupyter notebook was the only program accessing this file. I haven't opened this file on any other application.
# - I used this code to check if the file acutally exists or not in the directory where its supposed to be ```import os
# os.path.exists(r"D:\training\credencys-training-pyspark\python\database_operation")``` I got the result to be True.
# - I opened the directory in file manager where I noticed there were two temp files that were present in that directory. I simply deleted it. Deleting the temp files resolved this issue.
#
# <br>
#
# I still don't know why this glitch happened. I will look into it at a later date. This has never happend to be before when I used to use jupyter notebook on linux platforms.
#
# <br>
#
# **NOTICE:** It took a bit more time to resolve this issue and I found the solution by accident.
