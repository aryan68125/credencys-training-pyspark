# %% [markdown]
# # This Notebook contains the python code that performs operations on database

# %% [markdown]
# ## Import all necessary libraries

# %%
# import data manipulation libraries use in data science and analytics
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import itertools

# This library allows us to display data in table in html format with relying on pandas
from IPython.display import display, HTML

# import psycopg library to talk to the database
import psycopg2

# import pydaantic for type checking and insuring typesafety 
from pydantic import (BaseModel, EmailStr, Field, SecretStr, ValidationError)
from typing import (Optional, Any, Dict, List, Tuple)

# import sqlalchemy to manage database connections and carry out db operations
from sqlalchemy import (create_engine, inspect, text)
from sqlalchemy.engine import Engine

# importing python-decouple to help us access the secrets from a .env file
from decouple import (config, Config, RepositoryEnv)
# import path lib to set path for the env file
from pathlib import Path

# %% [markdown]
# ## Create database connection model and function to validate the database parameters.

# %%
# A pydantic model for database connection
# The reason I am using frozen in the fields in this model is because I don't want the fields to change after its setup for the first time
class DbConnManagerModel (BaseModel):
    host : str = Field(default=None, examples=["localhost"], frozen=True)
    database : str = Field(default=None, examples=["db_name"], frozen=True)
    user : str = Field(default=None, examples=["username"], frozen=True)
    password : str = Field(default=None, examples=["your_password"], frozen=True)
    port : int = Field(default=None, examples=[5432], frozen=True)

# %% [markdown]
# ## Tell jupyter notebook where to look for .env file

# %% [markdown]
# ### **NOTICE :**
# If your os platform is windows and you have created an .env file using file explorer like what I used to do in linux then windows has a tendency adding ```.text``` after the env file so your env file becomes like this ```.env.txt```. Beware of this when trying to use windows file exporer to create an env file. Use Vs code or jupyter notebook instead to create a ```.env``` file. <br>
# I will have to look into it a bit more no biggy.

# %%
env_path = Path("D:/training/credencys-training-pyspark/python/database_operation/.env")
config = Config(RepositoryEnv(env_path))

import os
os.path.exists(r"D:\training\credencys-training-pyspark\python\database_operation")
# Out:
# True

# %% [markdown]
# ### Explaination :
# #### RepositoryEnv:
# - This comes from the ```python-decouple``` library.
# - This library knows how to read a ```.env``` file.
# - It parses through the ```.env``` file and makes the key-value pair available.
# #### Config:
# - This ```Config``` library comes from ```python-decouple``` library.
# - ```Config``` is a wrapper around different configuration sources like (```.env``` files)
# - When I created ```Config(RepositoryEnv(env_path))``` I am telling it to load configuration values from the given ```.env``` file (via ```RepositoryEnv```)

# %% [markdown]
# ## Create a database connection using sql alchemy and create a connection object

# %%
# get the database connection prameters from the .env file and create a dictionary out of it
db_connection_params = {
    "host":config('host'),
    "database":config('database'),
    "user":config('user'),
    "password":config('password'),
    "port":config('port'),
}

# create a function to manage database connection
def database_engine(model_config:DbConnManagerModel) -> Engine:
    try:
        # validate connection parameters before creating a database connection object
        DBConnObj = DbConnManagerModel.model_validate(db_connection_params)
        print(f"DBConnObj : {DBConnObj}")
    
        # create a database engine
        engine = create_engine(
            f"postgresql+psycopg2://{DBConnObj.user}:{DBConnObj.password}@{DBConnObj.host}:{DBConnObj.port}/{DBConnObj.database}"
        )
        return engine
    except Exception as e:
        raise RuntimeError(f"failed to make connection with the database : {e}")

# create an databse engine object
engine_obj = database_engine(db_connection_params)
# Out:
# DBConnObj : host='localhost' database='training' user='postgres' password='1212' port=5432

# %% [markdown]
# ## Read a Table from the database table

# %% [markdown]
# ### Create a function to display data
# This function will be responsible to display the incoming data from the database in a table in jupyter notebook using html and css for this I am using IPython

# %%
# Create a function which is use the data returned by the "read_db_table_data" function
# to display the data nicely in a table using html code 
class DisplayDataModel(BaseModel):
    headers : List[str]
    rows : List[Tuple[Any,...]]
    
def display_data(display_model_config:DisplayDataModel) -> None:
    html = "<table border='1' style='border-collapse: collapse;'>"
    # Header row
    html += "<tr><th>S.no</th>" + "".join([f"<th>{h}</th>" for h in display_model_config.headers]) + "</tr>"
    # Data rows
    # using enumerate to get key value pairs on serial no and the actual data
    for i, row in enumerate(display_model_config.rows,start=1):  # limit rows for readability
        html += f"<tr><td>{i}</td>" + "".join([f"<td>{col}</td>" for col in row]) + "</tr>"
    html += "</table>"
    display(HTML(html))

# %% [markdown]
# ### Create a function to read data from the database using

# %%
# Created a pydantic model.
# This model is used to validate the parameters required to read the data from a table from the database
class ReadDbTableModel(BaseModel):
    table_name:str=Field(default=None)
    columns:List[str]=Field(default=[])
    engine:Engine
    max_rows : Optional[int] = Field(default=20)
    model_config = {
        "arbitrary_types_allowed":True
    }
    
# Create a function to read the data from the table in the database
def read_db_table_data(table_model_config:ReadDbTableModel) -> tuple[list[str], list[tuple[Any,...]]]:
    try:
        with table_model_config.engine.connect() as conn:
            if table_model_config.columns:
                query = text(f"SELECT {', '.join(table_model_config.columns)} FROM {table_model_config.table_name}")
            elif table_model_config.max_rows:
                query = text(f"SELECT * FROM {table_model_config.table_name} LIMIT {table_model_config.max_rows}")
            elif table_model_config.max_rows and table_model_config.columns:
                query = text(f"SELECT {', '.join(table_model_config.columns)} FROM {table_model_config.table_name} LIMIT {table_model_config.max_rows}")
            else:
                query = text(f"SELECT * FROM {table_model_config.table_name}")
            result = conn.execute(query)
            rows_data = result.fetchall()
            headers_data = result.keys()
        return headers_data,rows_data
    except Exception as e:
        raise RuntimeError(f"Cannot read the data from the table {table_model_config.table_name} : {e}")

# %% [markdown]
# ### NOTICE :
# If you are using passord type field in your pydantic model then using SecretStr is not a good idea in this case. Since we want to make connection to the database we have to use str instead to be able to successfully make a connection to the database otherwise we will get the error : "Authentication failed unable login into postgres"

# %% [markdown]
# ### Get all the columns from the table

# %%
config_read_customers_table = ReadDbTableModel(table_name="customers", engine=engine_obj)
headers_data, rows_data = read_db_table_data(config_read_customers_table)
display_obj = DisplayDataModel(headers=headers_data, rows=rows_data)
display_data(display_obj)
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>customer_id</th><th>city</th><th>state_province</th><th>country</th><th>region</th></tr><tr><td>1</td><td>39278</td><td>Naperville</td><td>Illinois</td><td>United States</td><td>Interior</td></tr><tr><td>2</td><td>21102</td><td>Henderson</td><td>Kentucky</td><td>United States</td><td>Gulf</td></tr><tr><td>3</td><td>21240</td><td>Los Angeles</td><td>California</td><td>United States</td><td>Pacific</td></tr><tr><td>4</td><td>32368</td><td>Huntsville</td><td>Texas</td><td>United States</td><td>Interior</td></tr><tr><td>5</td><td>25832</td><td>Laredo</td><td>Texas</td><td>United States</td><td>Interior</td></tr><tr><td>6</td><td>39448</td><td>Springfield</td><td>Virginia</td><td>United States</td><td>Gulf</td></tr><tr><td>7</td><td>11050</td><td>San Francisco</td><td>California</td><td>United States</td><td>Pacific</td></tr><tr><td>8</td><td>16678</td><td>Bossier City</td><td>Louisiana</td><td>United States</td><td>Gulf</td></tr><tr><td>9</td><td>36183</td><td>Mount Pleasant</td><td>South Carolina</td><td>United States</td><td>Gulf</td></tr><tr><td>10</td><td>45144</td><td>Newark</td><td>Ohio</td><td>United States</td><td>Atlantic</td></tr><tr><td>11</td><td>39952</td><td>Philadelphia</td><td>Pennsylvania</td><td>United States</td><td>Atlantic</td></tr><tr><td>12</td><td>30317</td><td>Roswell</td><td>Georgia</td><td>United States</td><td>Gulf</td></tr><tr><td>13</td><td>42743</td><td>Philadelphia</td><td>Pennsylvania</td><td>United States</td><td>Atlantic</td></tr><tr><td>14</td><td>37019</td><td>Scottsdale</td><td>Arizona</td><td>United States</td><td>Pacific</td></tr><tr><td>15</td><td>37374</td><td>Miami</td><td>Florida</td><td>United States</td><td>Gulf</td></tr><tr><td>16</td><td>29596</td><td>Las Vegas</td><td>Nevada</td><td>United States</td><td>Pacific</td></tr><tr><td>17</td><td>37425</td><td>Lafayette</td><td>Indiana</td><td>United States</td><td>Interior</td></tr><tr><td>18</td><td>45930</td><td>Alexandria</td><td>Virginia</td><td>United States</td><td>Gulf</td></tr><tr><td>19</td><td>44115</td><td>San Diego</td><td>California</td><td>United States</td><td>Pacific</td></tr><tr><td>20</td><td>31222</td><td>Green Bay</td><td>Wisconsin</td><td>United States</td><td>Interior</td></tr></table>

# %% [markdown]
# ### Get selected columns from the table

# %%
config_read_customers_table = ReadDbTableModel(table_name="customers", engine=engine_obj
                                               ,columns=["city","state_province"])
headers_data, rows_data = read_db_table_data(config_read_customers_table)
customers
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>city</th><th>state_province</th></tr><tr><td>1</td><td>Naperville</td><td>Illinois</td></tr><tr><td>2</td><td>Henderson</td><td>Kentucky</td></tr><tr><td>3</td><td>Los Angeles</td><td>California</td></tr><tr><td>4</td><td>Huntsville</td><td>Texas</td></tr><tr><td>5</td><td>Laredo</td><td>Texas</td></tr><tr><td>6</td><td>Springfield</td><td>Virginia</td></tr><tr><td>7</td><td>San Francisco</td><td>California</td></tr><tr><td>8</td><td>Bossier City</td><td>Louisiana</td></tr><tr><td>9</td><td>Mount Pleasant</td><td>South Carolina</td></tr><tr><td>10</td><td>Newark</td><td>Ohio</td></tr><tr><td>11</td><td>Philadelphia</td><td>Pennsylvania</td></tr><tr><td>12</td><td>Roswell</td><td>Georgia</td></tr><tr><td>13</td><td>Philadelphia</td><td>Pennsylvania</td></tr><tr><td>14</td><td>Scottsdale</td><td>Arizona</td></tr><tr><td>15</td><td>Miami</td><td>Florida</td></tr><tr><td>16</td><td>Las Vegas</td><td>Nevada</td></tr><tr><td>17</td><td>Lafayette</td><td>Indiana</td></tr><tr><td>18</td><td>Alexandria</td><td>Virginia</td></tr><tr><td>19</td><td>San Diego</td><td>California</td></tr><tr><td>20</td><td>Green Bay</td><td>Wisconsin</td></tr></table>
# (RMKeyView(['city', 'state_province']),
#  [('Naperville', 'Illinois'),
#   ('Henderson', 'Kentucky'),
#   ('Los Angeles', 'California'),
#   ('Huntsville', 'Texas'),
#   ('Laredo', 'Texas'),
#   ('Springfield', 'Virginia'),
#   ('San Francisco', 'California'),
#   ('Bossier City', 'Louisiana'),
#   ('Mount Pleasant', 'South Carolina'),
#   ('Newark', 'Ohio'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Roswell', 'Georgia'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Scottsdale', 'Arizona'),
#   ('Miami', 'Florida'),
#   ('Las Vegas', 'Nevada'),
#   ('Lafayette', 'Indiana'),
#   ('Alexandria', 'Virginia'),
#   ('San Diego', 'California'),
#   ('Green Bay', 'Wisconsin'),
#   ('Saint Petersburg', 'Florida'),
#   ('San Diego', 'California'),
#   ('Escondido', 'California'),
#   ('San Diego', 'California'),
#   ('North Las Vegas', 'Nevada'),
#   ('Columbia', 'Missouri'),
#   ('Seattle', 'Washington'),
#   ('Houston', 'Texas'),
#   ('Seattle', 'Washington'),
#   ('Arlington', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Richmond', 'Indiana'),
#   ('Woodstock', 'Illinois'),
#   ('Moreno Valley', 'California'),
#   ('El Paso', 'Texas'),
#   ('Medford', 'Oregon'),
#   ('El Paso', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Elmhurst', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Columbus', 'Ohio'),
#   ('San Diego', 'California'),
#   ('Wilmington', 'North Carolina'),
#   ('Columbia', 'South Carolina'),
#   ('Margate', 'Florida'),
#   ('Yonkers', 'New York'),
#   ('Des Moines', 'Washington'),
#   ('Seattle', 'Washington'),
#   ('Royal Oak', 'Michigan'),
#   ('Denver', 'Colorado'),
#   ('Roseville', 'California'),
#   ('Huntington Beach', 'California'),
#   ('Chesapeake', 'Virginia'),
#   ('Logan', 'Utah'),
#   ('Chicago', 'Illinois'),
#   ('Tampa', 'Florida'),
#   ('Raleigh', 'North Carolina'),
#   ('Dallas', 'Texas'),
#   ('Lakeville', 'Minnesota'),
#   ('San Francisco', 'California'),
#   ('Hamilton', 'Ohio'),
#   ('Asheville', 'North Carolina'),
#   ('Knoxville', 'Tennessee'),
#   ('Tucson', 'Arizona'),
#   ('Delray Beach', 'Florida'),
#   ('Fresno', 'California'),
#   ('New York City', 'New York'),
#   ('San Francisco', 'California'),
#   ('Pomona', 'California'),
#   ('Los Angeles', 'California'),
#   ('Des Moines', 'Iowa'),
#   ('Springfield', 'Ohio'),
#   ('Brownsville', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Apple Valley', 'Minnesota'),
#   ('San Francisco', 'California'),
#   ('Tampa', 'Florida'),
#   ('Miami', 'Florida'),
#   ('Chicago', 'Illinois'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Revere', 'Massachusetts'),
#   ('Houston', 'Texas'),
#   ('Athens', 'Georgia'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Lafayette', 'Louisiana'),
#   ('Alexandria', 'Virginia'),
#   ('Dearborn Heights', 'Michigan'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Mobile', 'Alabama'),
#   ('Marietta', 'Georgia'),
#   ('Chandler', 'Arizona'),
#   ('Concord', 'California'),
#   ('Lewiston', 'Idaho'),
#   ('Lodi', 'California'),
#   ('Redondo Beach', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Baltimore', 'Maryland'),
#   ('Los Angeles', 'California'),
#   ('Wilmington', 'North Carolina'),
#   ('Houston', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('San Jose', 'California'),
#   ('Los Angeles', 'California'),
#   ('Henderson', 'Kentucky'),
#   ('Troy', 'New York'),
#   ('San Francisco', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Wilmington', 'North Carolina'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Newark', 'Ohio'),
#   ('Baltimore', 'Maryland'),
#   ('Louisville', 'Kentucky'),
#   ('Jackson', 'Mississippi'),
#   ('Lakeland', 'Florida'),
#   ('Appleton', 'Wisconsin'),
#   ('Yonkers', 'New York'),
#   ('Houston', 'Texas'),
#   ('Jackson', 'Michigan'),
#   ('Middletown', 'Connecticut'),
#   ('San Antonio', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Lawrence', 'Massachusetts'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Henderson', 'Kentucky'),
#   ('San Francisco', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Watertown', 'New York'),
#   ('Houston', 'Texas'),
#   ('Fort Worth', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('Milwaukee', 'Wisconsin'),
#   ('Franklin', 'Massachusetts'),
#   ('West Jordan', 'Utah'),
#   ('Hialeah', 'Florida'),
#   ('Los Angeles', 'California'),
#   ('Oakland', 'California'),
#   ('Saint Petersburg', 'Florida'),
#   ('Los Angeles', 'California'),
#   ('San Francisco', 'California'),
#   ('Eau Claire', 'Wisconsin'),
#   ('Akron', 'Ohio'),
#   ('Dallas', 'Texas'),
#   ('Midland', 'Michigan'),
#   ('Dover', 'New Hampshire'),
#   ('San Diego', 'California'),
#   ('Lawrence', 'Massachusetts'),
#   ('Virginia Beach', 'Virginia'),
#   ('Decatur', 'Alabama'),
#   ('Bellevue', 'Washington'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Baltimore', 'Maryland'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Murray', 'Utah'),
#   ('Chicago', 'Illinois'),
#   ('San Diego', 'California'),
#   ('San Francisco', 'California'),
#   ('Chicago', 'Illinois'),
#   ('Seattle', 'Washington'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('Buffalo Grove', 'Illinois'),
#   ('Jackson', 'Mississippi'),
#   ('Detroit', 'Michigan'),
#   ('Lakeville', 'Minnesota'),
#   ('Seattle', 'Washington'),
#   ('Midland', 'Michigan'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('Rochester', 'New York'),
#   ('Aurora', 'Illinois'),
#   ('Bristol', 'Tennessee'),
#   ('North Las Vegas', 'Nevada'),
#   ('San Francisco', 'California'),
#   ('Los Angeles', 'California'),
#   ('Detroit', 'Michigan'),
#   ('Los Angeles', 'California'),
#   ('Detroit', 'Michigan'),
#   ('El Paso', 'Texas'),
#   ('San Antonio', 'Texas'),
#   ('Hempstead', 'New York'),
#   ('Newark', 'Delaware'),
#   ('Chicago', 'Illinois'),
#   ('Los Angeles', 'California'),
#   ('Halifax', 'Nova Scotia'),
#   ('Lawton', 'Oklahoma'),
#   ('Pueblo', 'Colorado'),
#   ('Lakewood', 'New Jersey'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Meriden', 'Connecticut'),
#   ('Waynesboro', 'Virginia'),
#   ('Phoenix', 'Arizona'),
#   ('Louisville', 'Colorado'),
#   ('Tucson', 'Arizona'),
#   ('Southaven', 'Mississippi'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Cincinnati', 'Ohio'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Wilmington', 'North Carolina'),
#   ('Deltona', 'Florida'),
#   ('Seattle', 'Washington'),
#   ('Plainfield', 'New Jersey'),
#   ('Aurora', 'Colorado'),
#   ('Jackson', 'Mississippi'),
#   ('Palm Coast', 'Florida'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Buffalo', 'New York'),
#   ('Dallas', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Los Angeles', 'California'),
#   ('Hackensack', 'New Jersey'),
#   ('New York City', 'New York'),
#   ('League City', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Newark', 'Delaware'),
#   ('New York City', 'New York'),
#   ('Phoenix', 'Arizona'),
#   ('New Rochelle', 'New York'),
#   ('Great Falls', 'Montana'),
#   ('Bristol', 'Connecticut'),
#   ('San Francisco', 'California'),
#   ('Riverside', 'California'),
#   ('Springfield', 'Ohio'),
#   ('Dallas', 'Texas'),
#   ('Dallas', 'Texas'),
#   ('Omaha', 'Nebraska'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('San Francisco', 'California'),
#   ('Tucson', 'Arizona'),
#   ('San Francisco', 'California'),
#   ('Los Angeles', 'California'),
#   ('Draper', 'Utah'),
#   ('North Las Vegas', 'Nevada'),
#   ('San Antonio', 'Texas'),
#   ('Atlanta', 'Georgia'),
#   ('Chicago', 'Illinois'),
#   ('San Francisco', 'California'),
#   ('New York City', 'New York'),
#   ('Apopka', 'Florida'),
#   ('Seattle', 'Washington'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Charlotte', 'North Carolina'),
#   ('Glendale', 'Arizona'),
#   ('Denver', 'Colorado'),
#   ('New York City', 'New York'),
#   ('Meriden', 'Connecticut'),
#   ('Columbia', 'South Carolina'),
#   ('Glendale', 'Arizona'),
#   ('Vacaville', 'California'),
#   ('Jacksonville', 'Florida'),
#   ('Seattle', 'Washington'),
#   ('Saint Petersburg', 'Florida'),
#   ('Fresno', 'California'),
#   ('San Diego', 'California'),
#   ('Lakewood', 'New Jersey'),
#   ('San Francisco', 'California'),
#   ('Woodstock', 'Georgia'),
#   ('Miami', 'Florida'),
#   ('Dallas', 'Texas'),
#   ('Hollywood', 'Florida'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Houston', 'Texas'),
#   ('Little Rock', 'Arkansas'),
#   ('Columbus', 'Ohio'),
#   ('Los Angeles', 'California'),
#   ('Jonesboro', 'Arkansas'),
#   ('Chicago', 'Illinois'),
#   ('Hampton', 'Virginia'),
#   ('Lakewood', 'Ohio'),
#   ('North Miami', 'Florida'),
#   ('Denver', 'Colorado'),
#   ('New York City', 'New York'),
#   ('Oceanside', 'New York'),
#   ('Owensboro', 'Kentucky'),
#   ('Houston', 'Texas'),
#   ('Seattle', 'Washington'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Newark', 'Delaware'),
#   ('Newark', 'Delaware'),
#   ('Springfield', 'Virginia'),
#   ('San Francisco', 'California'),
#   ('Miami', 'Florida'),
#   ('San Francisco', 'California'),
#   ('Bristol', 'Connecticut'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('Watertown', 'New York'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('Saint Petersburg', 'Florida'),
#   ('Bowling Green', 'Ohio'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Houston', 'Texas'),
#   ('Santa Clara', 'California'),
#   ('Tulsa', 'Oklahoma'),
#   ('Macon', 'Georgia'),
#   ('San Francisco', 'California'),
#   ('San Francisco', 'California'),
#   ('San Antonio', 'Texas'),
#   ('Pasco', 'Washington'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('Lowell', 'Massachusetts'),
#   ('Chicago', 'Illinois'),
#   ('Detroit', 'Michigan'),
#   ('Greenville', 'North Carolina'),
#   ('Gresham', 'Oregon'),
#   ('Oxnard', 'California'),
#   ('New Rochelle', 'New York'),
#   ('Cary', 'North Carolina'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Tempe', 'Arizona'),
#   ('Odessa', 'Texas'),
#   ('Macon', 'Georgia'),
#   ('Corpus Christi', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Springfield', 'Oregon'),
#   ('Seattle', 'Washington'),
#   ('Chula Vista', 'California'),
#   ('Raleigh', 'North Carolina'),
#   ('San Francisco', 'California'),
#   ('Charlotte', 'North Carolina'),
#   ('Seattle', 'Washington'),
#   ('Chandler', 'Arizona'),
#   ('Houston', 'Texas'),
#   ('Long Beach', 'California'),
#   ('New York City', 'New York'),
#   ('San Diego', 'California'),
#   ('Los Angeles', 'California'),
#   ('Bloomington', 'Illinois'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Garland', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Des Moines', 'Washington'),
#   ('San Francisco', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Dover', 'Delaware'),
#   ('San Diego', 'California'),
#   ('Minneapolis', 'Minnesota'),
#   ('Aurora', 'Colorado'),
#   ('Houston', 'Texas'),
#   ('Seattle', 'Washington'),
#   ('San Diego', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Mesquite', 'Texas'),
#   ('Hackensack', 'New Jersey'),
#   ('San Diego', 'California'),
#   ('Fayetteville', 'North Carolina'),
#   ('Lawrence', 'Massachusetts'),
#   ('Hollywood', 'Florida'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Fairfield', 'Ohio'),
#   ('Reno', 'Nevada'),
#   ('Tempe', 'Arizona'),
#   ('Los Angeles', 'California'),
#   ('Evanston', 'Illinois'),
#   ('Durham', 'North Carolina'),
#   ('New York City', 'New York'),
#   ('Seattle', 'Washington'),
#   ('Vallejo', 'California'),
#   ('Pomona', 'California'),
#   ('Columbus', 'Ohio'),
#   ('San Diego', 'California'),
#   ('Indianapolis', 'Indiana'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Charlotte', 'North Carolina'),
#   ('New York City', 'New York'),
#   ('Jacksonville', 'North Carolina'),
#   ('San Francisco', 'California'),
#   ('Albuquerque', 'New Mexico'),
#   ('Huntsville', 'Texas'),
#   ('Columbus', 'Ohio'),
#   ('Phoenix', 'Arizona'),
#   ('Pasadena', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Redondo Beach', 'California'),
#   ('Fayetteville', 'Arkansas'),
#   ('San Francisco', 'California'),
#   ('Chicago', 'Illinois'),
#   ('Mount Vernon', 'New York'),
#   ('Lakewood', 'New Jersey'),
#   ('Richmond', 'Virginia'),
#   ('Chicago', 'Illinois'),
#   ('Everett', 'Massachusetts'),
#   ('Hialeah', 'Florida'),
#   ('San Francisco', 'California'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Texarkana', 'Arkansas'),
#   ('Lakewood', 'California'),
#   ('Los Angeles', 'California'),
#   ('San Francisco', 'California'),
#   ('Knoxville', 'Tennessee'),
#   ('Chicago', 'Illinois'),
#   ('Newport News', 'Virginia'),
#   ('Fairfield', 'Ohio'),
#   ('Newark', 'Ohio'),
#   ('Rancho Cucamonga', 'California'),
#   ('Fort Lauderdale', 'Florida'),
#   ('Rock Hill', 'South Carolina'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Fayetteville', 'North Carolina'),
#   ('Garden City', 'Kansas'),
#   ('Columbus', 'Indiana'),
#   ('Chicago', 'Illinois'),
#   ('Avondale', 'Arizona'),
#   ('Los Angeles', 'California'),
#   ('Lorain', 'Ohio'),
#   ('Portland', 'Oregon'),
#   ('Richmond', 'Kentucky'),
#   ('Fort Lauderdale', 'Florida'),
#   ('Medina', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Omaha', 'Nebraska'),
#   ('Jacksonville', 'North Carolina'),
#   ('Lancaster', 'Pennsylvania'),
#   ('Nashville', 'Tennessee'),
#   ('Fairfield', 'Connecticut'),
#   ('Orange', 'New Jersey'),
#   ('Cary', 'North Carolina'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('San Diego', 'California'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Hampton', 'Virginia'),
#   ('Columbus', 'Georgia'),
#   ('San Francisco', 'California'),
#   ('Houston', 'Texas'),
#   ('Wausau', 'Wisconsin'),
#   ('Midland', 'Michigan'),
#   ('San Diego', 'California'),
#   ('Louisville', 'Colorado'),
#   ('Seattle', 'Washington'),
#   ('Houston', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('Los Angeles', 'California'),
#   ('New Rochelle', 'New York'),
#   ('Reading', 'Pennsylvania'),
#   ('Carrollton', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Asheville', 'North Carolina'),
#   ('San Antonio', 'Texas'),
#   ('Chesapeake', 'Virginia'),
#   ('Fairfield', 'Connecticut'),
#   ('Midland', 'Michigan'),
#   ('New York City', 'New York'),
#   ('Pasadena', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Huntington Beach', 'California'),
#   ('Bloomington', 'Indiana'),
#   ('Manhattan', 'Kansas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Moorhead', 'Minnesota'),
#   ('Newark', 'Delaware'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Seattle', 'Washington'),
#   ('Louisville', 'Colorado'),
#   ('Minneapolis', 'Minnesota'),
#   ('Provo', 'Utah'),
#   ('Monroe', 'Louisiana'),
#   ('Jamestown', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Coon Rapids', 'Minnesota'),
#   ('Dallas', 'Texas'),
#   ('Richmond', 'Kentucky'),
#   ('San Francisco', 'California'),
#   ('San Francisco', 'California'),
#   ('Atlanta', 'Georgia'),
#   ('Columbus', 'Georgia'),
#   ('Los Angeles', 'California'),
#   ('Pasadena', 'Texas'),
#   ('Bolingbrook', 'Illinois'),
#   ('Mesquite', 'Texas'),
#   ('Scottsdale', 'Arizona'),
#   ('Detroit', 'Michigan'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Chicago', 'Illinois'),
#   ('Saint Louis', 'Missouri'),
#   ('Sacramento', 'California'),
#   ('Columbus', 'Ohio'),
#   ('Cincinnati', 'Ohio'),
#   ("St. John's", 'Newfoundland and Labrador'),
#   ('Toledo', 'Ohio'),
#   ('Woonsocket', 'Rhode Island'),
#   ('Arlington', 'Texas'),
#   ('Springfield', 'Oregon'),
#   ('Tigard', 'Oregon'),
#   ('San Francisco', 'California'),
#   ('Buffalo', 'New York'),
#   ('San Francisco', 'California'),
#   ('Richmond', 'Indiana'),
#   ('Skokie', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Avondale', 'Arizona'),
#   ('Orlando', 'Florida'),
#   ('Houston', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Jacksonville', 'North Carolina'),
#   ('Lowell', 'Massachusetts'),
#   ('Columbus', 'Ohio'),
#   ('Madison', 'Wisconsin'),
#   ('Chicago', 'Illinois'),
#   ('Corpus Christi', 'Texas'),
#   ('Moncton', 'New Brunswick'),
#   ('Oklahoma City', 'Oklahoma'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Columbus', 'Ohio'),
#   ('Chicago', 'Illinois'),
#   ('Houston', 'Texas'),
#   ('Springfield', 'Oregon'),
#   ('Memphis', 'Tennessee'),
#   ('Virginia Beach', 'Virginia'),
#   ('Seattle', 'Washington'),
#   ('Olympia', 'Washington'),
#   ('Chicago', 'Illinois'),
#   ('Mesa', 'Arizona'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Brownsville', 'Texas'),
#   ('New York City', 'New York'),
#   ('San Antonio', 'Texas'),
#   ('Fresno', 'California'),
#   ('Concord', 'California'),
#   ('Miami', 'Florida'),
#   ('Phoenix', 'Arizona'),
#   ('Los Angeles', 'California'),
#   ('Marion', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('Deltona', 'Florida'),
#   ('Springfield', 'Virginia'),
#   ('Beaumont', 'Texas'),
#   ('Detroit', 'Michigan'),
#   ('Hialeah', 'Florida'),
#   ('Columbus', 'Georgia'),
#   ('Florence', 'Alabama'),
#   ('Los Angeles', 'California'),
#   ('Chicago', 'Illinois'),
#   ('Grand Prairie', 'Texas'),
#   ('Hamilton', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Columbia', 'Tennessee'),
#   ('Indianapolis', 'Indiana'),
#   ('Thornton', 'Colorado'),
#   ('Los Angeles', 'California'),
#   ('San Diego', 'California'),
#   ('San Jose', 'California'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Port Arthur', 'Texas'),
#   ('Richmond', 'Indiana'),
#   ('Tampa', 'Florida'),
#   ('Los Angeles', 'California'),
#   ('Miami', 'Florida'),
#   ('Cleveland', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Chicago', 'Illinois'),
#   ('Skokie', 'Illinois'),
#   ('Fort Worth', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Phoenix', 'Arizona'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Beverly', 'Massachusetts'),
#   ('Kent', 'Ohio'),
#   ('Brentwood', 'California'),
#   ('Quebec City', 'Quebec'),
#   ('Cottage Grove', 'Minnesota'),
#   ('San Francisco', 'California'),
#   ('Memphis', 'Tennessee'),
#   ('Taylor', 'Michigan'),
#   ('New York City', 'New York'),
#   ('Phoenix', 'Arizona'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Reno', 'Nevada'),
#   ('Columbia', 'Missouri'),
#   ('Watertown', 'New York'),
#   ('Medina', 'Ohio'),
#   ('Dallas', 'Texas'),
#   ('Woodbury', 'Minnesota'),
#   ('San Francisco', 'California'),
#   ('Colorado Springs', 'Colorado'),
#   ('Henderson', 'Kentucky'),
#   ('Toledo', 'Ohio'),
#   ('Newark', 'Delaware'),
#   ('Columbus', 'Georgia'),
#   ('Park Ridge', 'Illinois'),
#   ('Bartlett', 'Tennessee'),
#   ('Texas City', 'Texas'),
#   ('Bozeman', 'Montana'),
#   ('West Palm Beach', 'Florida'),
#   ('Cleveland', 'Ohio'),
#   ('Concord', 'North Carolina'),
#   ('Los Angeles', 'California'),
#   ('Houston', 'Texas'),
#   ('Minneapolis', 'Minnesota'),
#   ('Rome', 'New York'),
#   ('Pleasant Grove', 'Utah'),
#   ('Columbus', 'Georgia'),
#   ('Omaha', 'Nebraska'),
#   ('Garden City', 'Kansas'),
#   ('Columbus', 'Ohio'),
#   ('Dallas', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Rochester', 'New York'),
#   ('Dover', 'New Hampshire'),
#   ('Los Angeles', 'California'),
#   ('Perth Amboy', 'New Jersey'),
#   ('Columbia', 'Maryland'),
#   ('Las Cruces', 'New Mexico'),
#   ('Seattle', 'Washington'),
#   ('Providence', 'Rhode Island'),
#   ('Altoona', 'Pennsylvania'),
#   ('Columbia', 'Tennessee'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Houston', 'Texas'),
#   ('Coppell', 'Texas'),
#   ('Richmond', 'Indiana'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('New Castle', 'Indiana'),
#   ('Houston', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Kenosha', 'Wisconsin'),
#   ('Pueblo', 'Colorado'),
#   ('Raleigh', 'North Carolina'),
#   ('Clinton', 'Maryland'),
#   ('Dover', 'New Hampshire'),
#   ('Roseville', 'California'),
#   ('Lehi', 'Utah'),
#   ('Auburn', 'Alabama'),
#   ('Atlanta', 'Georgia'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Houston', 'Texas'),
#   ('North Miami', 'Florida'),
#   ('Lancaster', 'California'),
#   ('New York City', 'New York'),
#   ('Milwaukee', 'Wisconsin'),
#   ('Jacksonville', 'North Carolina'),
#   ('Montreal', 'Quebec'),
#   ('Houston', 'Texas'),
#   ('Huntsville', 'Alabama'),
#   ('San Diego', 'California'),
#   ('Houston', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Covington', 'Washington'),
#   ('Coral Springs', 'Florida'),
#   ('Peoria', 'Illinois'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Seattle', 'Washington'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Seattle', 'Washington'),
#   ('San Diego', 'California'),
#   ('New York City', 'New York'),
#   ('Springfield', 'Virginia'),
#   ('Jacksonville', 'Florida'),
#   ('Normal', 'Illinois'),
#   ('Houston', 'Texas'),
#   ('Jacksonville', 'Florida'),
#   ('Dallas', 'Texas'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('Lansing', 'Michigan'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Bristol', 'Tennessee'),
#   ('Spokane', 'Washington'),
#   ('Houston', 'Texas'),
#   ('Jacksonville', 'North Carolina'),
#   ('Long Beach', 'California'),
#   ('Sacramento', 'California'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('Norfolk', 'Nebraska'),
#   ('Glendale', 'Arizona'),
#   ('Mesa', 'Arizona'),
#   ('Farmington', 'New Mexico'),
#   ('Los Angeles', 'California'),
#   ('Toledo', 'Ohio'),
#   ('Waynesboro', 'Virginia'),
#   ('New York City', 'New York'),
#   ('Mcallen', 'Texas'),
#   ('Monroe', 'Louisiana'),
#   ('Los Angeles', 'California'),
#   ('Santa Maria', 'California'),
#   ('Carrollton', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Detroit', 'Michigan'),
#   ('Louisville', 'Kentucky'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('Aurora', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Milwaukee', 'Wisconsin'),
#   ('Daytona Beach', 'Florida'),
#   ('Houston', 'Texas'),
#   ('Washington', 'District of Columbia'),
#   ('Aurora', 'Colorado'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Chicago', 'Illinois'),
#   ('Lawrence', 'Massachusetts'),
#   ('Los Angeles', 'California'),
#   ('Houston', 'Texas'),
#   ('San Jose', 'California'),
#   ('Chula Vista', 'California'),
#   ('New York City', 'New York'),
#   ('Indianapolis', 'Indiana'),
#   ('Houston', 'Texas'),
#   ('Toronto', 'Ontario'),
#   ('Owensboro', 'Kentucky'),
#   ('Minneapolis', 'Minnesota'),
#   ('New York City', 'New York'),
#   ('Salem', 'Oregon'),
#   ('Cuyahoga Falls', 'Ohio'),
#   ('Aurora', 'Illinois'),
#   ('Louisville', 'Colorado'),
#   ('San Francisco', 'California'),
#   ('Louisville', 'Colorado'),
#   ('Houston', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('Los Angeles', 'California'),
#   ('Camarillo', 'California'),
#   ('Chester', 'Pennsylvania'),
#   ('Roswell', 'Georgia'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Long Beach', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('Phoenix', 'Arizona'),
#   ('Columbia', 'South Carolina'),
#   ('Woonsocket', 'Rhode Island'),
#   ('Naperville', 'Illinois'),
#   ('Pueblo', 'Colorado'),
#   ('Columbia', 'Tennessee'),
#   ('Wichita', 'Kansas'),
#   ('San Antonio', 'Texas'),
#   ('Bellevue', 'Washington'),
#   ('Rochester', 'New York'),
#   ('Manchester', 'Connecticut'),
#   ('Seattle', 'Washington'),
#   ('Indianapolis', 'Indiana'),
#   ('Cleveland', 'Ohio'),
#   ('Springfield', 'Virginia'),
#   ('New York City', 'New York'),
#   ('Minneapolis', 'Minnesota'),
#   ('San Jose', 'California'),
#   ('Norwich', 'Connecticut'),
#   ('Fayetteville', 'North Carolina'),
#   ('Long Beach', 'New York'),
#   ('Detroit', 'Michigan'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Saint Charles', 'Missouri'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Los Angeles', 'California'),
#   ('Saint Petersburg', 'Florida'),
#   ('Pocatello', 'Idaho'),
#   ('Royal Oak', 'Michigan'),
#   ('Hampton', 'Virginia'),
#   ('Lakeland', 'Florida'),
#   ('Monroe', 'Louisiana'),
#   ('Newark', 'Delaware'),
#   ('Columbus', 'Indiana'),
#   ('Decatur', 'Alabama'),
#   ('Lewiston', 'Maine'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Gilbert', 'Arizona'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Grand Prairie', 'Texas'),
#   ('Peoria', 'Arizona'),
#   ('Miami', 'Florida'),
#   ('San Diego', 'California'),
#   ('Smyrna', 'Tennessee'),
#   ('Los Angeles', 'California'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Deltona', 'Florida'),
#   ('Layton', 'Utah'),
#   ('Rochester', 'New York'),
#   ('Long Beach', 'California'),
#   ('East Point', 'Georgia'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Houston', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Lakewood', 'Ohio'),
#   ('Richmond', 'Virginia'),
#   ('Gilbert', 'Arizona'),
#   ('Lancaster', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Carol Stream', 'Illinois'),
#   ('Hollywood', 'Florida'),
#   ('New York City', 'New York'),
#   ('Houston', 'Texas'),
#   ('Richmond', 'Kentucky'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Sterling Heights', 'Michigan'),
#   ('Fayetteville', 'North Carolina'),
#   ('Pasadena', 'California'),
#   ('New York City', 'New York'),
#   ('Holyoke', 'Massachusetts'),
#   ('Vineland', 'New Jersey'),
#   ('Houston', 'Texas'),
#   ('Dallas', 'Texas'),
#   ('Clinton', 'Maryland'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Franklin', 'Massachusetts'),
#   ('Nashville', 'Tennessee'),
#   ('Tempe', 'Arizona'),
#   ('Wilmington', 'Delaware'),
#   ('Seattle', 'Washington'),
#   ('Chicago', 'Illinois'),
#   ('Amarillo', 'Texas'),
#   ('Mesa', 'Arizona'),
#   ('Baltimore', 'Maryland'),
#   ('San Francisco', 'California'),
#   ('Bakersfield', 'California'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Highland Park', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Louisville', 'Kentucky'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Mesa', 'Arizona'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Oxnard', 'California'),
#   ('Lakeville', 'Minnesota'),
#   ('Houston', 'Texas'),
#   ('San Francisco', 'California'),
#   ('New York City', 'New York'),
#   ('Hattiesburg', 'Mississippi'),
#   ('Saint Louis', 'Missouri'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('Dallas', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Kirkwood', 'Missouri'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Bakersfield', 'California'),
#   ('San Francisco', 'California'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Milwaukee', 'Wisconsin'),
#   ('Jacksonville', 'Florida'),
#   ('Redmond', 'Oregon'),
#   ('Raleigh', 'North Carolina'),
#   ('New York City', 'New York'),
#   ('Greensboro', 'North Carolina'),
#   ('Richmond', 'Indiana'),
#   ('Marietta', 'Georgia'),
#   ('Los Angeles', 'California'),
#   ('Phoenix', 'Arizona'),
#   ('Florence', 'Kentucky'),
#   ('San Francisco', 'California'),
#   ('Allentown', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Springfield', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Bolingbrook', 'Illinois'),
#   ('Bowling Green', 'Ohio'),
#   ('Florence', 'Kentucky'),
#   ('New York City', 'New York'),
#   ('Arlington', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('San Diego', 'California'),
#   ('Los Angeles', 'California'),
#   ('Dallas', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('Fairfield', 'Connecticut'),
#   ('Detroit', 'Michigan'),
#   ('San Diego', 'California'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('San Francisco', 'California'),
#   ('San Francisco', 'California'),
#   ('Durham', 'North Carolina'),
#   ('Tucson', 'Arizona'),
#   ('Houston', 'Texas'),
#   ('Medford', 'Oregon'),
#   ('Houston', 'Texas'),
#   ('San Diego', 'California'),
#   ('Rochester', 'Minnesota'),
#   ('Richmond', 'Virginia'),
#   ('Tamarac', 'Florida'),
#   ('Seattle', 'Washington'),
#   ('La Quinta', 'California'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('El Paso', 'Texas'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Pasadena', 'California'),
#   ('Montgomery', 'Alabama'),
#   ('Los Angeles', 'California'),
#   ('Austin', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Revere', 'Massachusetts'),
#   ('Paterson', 'New Jersey'),
#   ('Aurora', 'Colorado'),
#   ('Redlands', 'California'),
#   ('New York City', 'New York'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Anaheim', 'California'),
#   ('Chicago', 'Illinois'),
#   ('Atlanta', 'Georgia'),
#   ('North Charleston', 'South Carolina'),
#   ('Los Angeles', 'California'),
#   ('Des Moines', 'Iowa'),
#   ('Provo', 'Utah'),
#   ('Coral Springs', 'Florida'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Diego', 'California'),
#   ('Clinton', 'Maryland'),
#   ('Long Beach', 'California'),
#   ('Des Moines', 'Washington'),
#   ('Los Angeles', 'California'),
#   ('Santa Fe', 'New Mexico'),
#   ('Columbus', 'Georgia'),
#   ('Sacramento', 'California'),
#   ('Naperville', 'Illinois'),
#   ('Nashville', 'Tennessee'),
#   ('Las Vegas', 'Nevada'),
#   ('Lawrence', 'Massachusetts'),
#   ('Long Beach', 'New York'),
#   ('Quincy', 'Massachusetts'),
#   ('Seattle', 'Washington'),
#   ('Oceanside', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Avondale', 'Arizona'),
#   ('Tucson', 'Arizona'),
#   ('Columbus', 'Ohio'),
#   ...])

# %% [markdown]
# ### Get data of 80 rows from the table

# %%
config_read_customers_table = ReadDbTableModel(table_name="customers", engine=engine_obj
                                               ,columns=["city","state_province"], max_rows=80)
customers = read_db_table_data(config_read_customers_table)
customers
# Out:
# <table border='1' style='border-collapse: collapse;'><tr><th>S.no</th><th>city</th><th>state_province</th></tr><tr><td>1</td><td>Naperville</td><td>Illinois</td></tr><tr><td>2</td><td>Henderson</td><td>Kentucky</td></tr><tr><td>3</td><td>Los Angeles</td><td>California</td></tr><tr><td>4</td><td>Huntsville</td><td>Texas</td></tr><tr><td>5</td><td>Laredo</td><td>Texas</td></tr><tr><td>6</td><td>Springfield</td><td>Virginia</td></tr><tr><td>7</td><td>San Francisco</td><td>California</td></tr><tr><td>8</td><td>Bossier City</td><td>Louisiana</td></tr><tr><td>9</td><td>Mount Pleasant</td><td>South Carolina</td></tr><tr><td>10</td><td>Newark</td><td>Ohio</td></tr><tr><td>11</td><td>Philadelphia</td><td>Pennsylvania</td></tr><tr><td>12</td><td>Roswell</td><td>Georgia</td></tr><tr><td>13</td><td>Philadelphia</td><td>Pennsylvania</td></tr><tr><td>14</td><td>Scottsdale</td><td>Arizona</td></tr><tr><td>15</td><td>Miami</td><td>Florida</td></tr><tr><td>16</td><td>Las Vegas</td><td>Nevada</td></tr><tr><td>17</td><td>Lafayette</td><td>Indiana</td></tr><tr><td>18</td><td>Alexandria</td><td>Virginia</td></tr><tr><td>19</td><td>San Diego</td><td>California</td></tr><tr><td>20</td><td>Green Bay</td><td>Wisconsin</td></tr><tr><td>21</td><td>Saint Petersburg</td><td>Florida</td></tr><tr><td>22</td><td>San Diego</td><td>California</td></tr><tr><td>23</td><td>Escondido</td><td>California</td></tr><tr><td>24</td><td>San Diego</td><td>California</td></tr><tr><td>25</td><td>North Las Vegas</td><td>Nevada</td></tr><tr><td>26</td><td>Columbia</td><td>Missouri</td></tr><tr><td>27</td><td>Seattle</td><td>Washington</td></tr><tr><td>28</td><td>Houston</td><td>Texas</td></tr><tr><td>29</td><td>Seattle</td><td>Washington</td></tr><tr><td>30</td><td>Arlington</td><td>Texas</td></tr><tr><td>31</td><td>Los Angeles</td><td>California</td></tr><tr><td>32</td><td>Richmond</td><td>Indiana</td></tr><tr><td>33</td><td>Woodstock</td><td>Illinois</td></tr><tr><td>34</td><td>Moreno Valley</td><td>California</td></tr><tr><td>35</td><td>El Paso</td><td>Texas</td></tr><tr><td>36</td><td>Medford</td><td>Oregon</td></tr><tr><td>37</td><td>El Paso</td><td>Texas</td></tr><tr><td>38</td><td>Houston</td><td>Texas</td></tr><tr><td>39</td><td>Seattle</td><td>Washington</td></tr><tr><td>40</td><td>New York City</td><td>New York</td></tr><tr><td>41</td><td>Elmhurst</td><td>Illinois</td></tr><tr><td>42</td><td>New York City</td><td>New York</td></tr><tr><td>43</td><td>Philadelphia</td><td>Pennsylvania</td></tr><tr><td>44</td><td>Columbus</td><td>Ohio</td></tr><tr><td>45</td><td>San Diego</td><td>California</td></tr><tr><td>46</td><td>Wilmington</td><td>North Carolina</td></tr><tr><td>47</td><td>Columbia</td><td>South Carolina</td></tr><tr><td>48</td><td>Margate</td><td>Florida</td></tr><tr><td>49</td><td>Yonkers</td><td>New York</td></tr><tr><td>50</td><td>Des Moines</td><td>Washington</td></tr><tr><td>51</td><td>Seattle</td><td>Washington</td></tr><tr><td>52</td><td>Royal Oak</td><td>Michigan</td></tr><tr><td>53</td><td>Denver</td><td>Colorado</td></tr><tr><td>54</td><td>Roseville</td><td>California</td></tr><tr><td>55</td><td>Huntington Beach</td><td>California</td></tr><tr><td>56</td><td>Chesapeake</td><td>Virginia</td></tr><tr><td>57</td><td>Logan</td><td>Utah</td></tr><tr><td>58</td><td>Chicago</td><td>Illinois</td></tr><tr><td>59</td><td>Tampa</td><td>Florida</td></tr><tr><td>60</td><td>Raleigh</td><td>North Carolina</td></tr><tr><td>61</td><td>Dallas</td><td>Texas</td></tr><tr><td>62</td><td>Lakeville</td><td>Minnesota</td></tr><tr><td>63</td><td>San Francisco</td><td>California</td></tr><tr><td>64</td><td>Hamilton</td><td>Ohio</td></tr><tr><td>65</td><td>Asheville</td><td>North Carolina</td></tr><tr><td>66</td><td>Knoxville</td><td>Tennessee</td></tr><tr><td>67</td><td>Tucson</td><td>Arizona</td></tr><tr><td>68</td><td>Delray Beach</td><td>Florida</td></tr><tr><td>69</td><td>Fresno</td><td>California</td></tr><tr><td>70</td><td>New York City</td><td>New York</td></tr><tr><td>7 ...
# (RMKeyView(['city', 'state_province']),
#  [('Naperville', 'Illinois'),
#   ('Henderson', 'Kentucky'),
#   ('Los Angeles', 'California'),
#   ('Huntsville', 'Texas'),
#   ('Laredo', 'Texas'),
#   ('Springfield', 'Virginia'),
#   ('San Francisco', 'California'),
#   ('Bossier City', 'Louisiana'),
#   ('Mount Pleasant', 'South Carolina'),
#   ('Newark', 'Ohio'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Roswell', 'Georgia'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Scottsdale', 'Arizona'),
#   ('Miami', 'Florida'),
#   ('Las Vegas', 'Nevada'),
#   ('Lafayette', 'Indiana'),
#   ('Alexandria', 'Virginia'),
#   ('San Diego', 'California'),
#   ('Green Bay', 'Wisconsin'),
#   ('Saint Petersburg', 'Florida'),
#   ('San Diego', 'California'),
#   ('Escondido', 'California'),
#   ('San Diego', 'California'),
#   ('North Las Vegas', 'Nevada'),
#   ('Columbia', 'Missouri'),
#   ('Seattle', 'Washington'),
#   ('Houston', 'Texas'),
#   ('Seattle', 'Washington'),
#   ('Arlington', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Richmond', 'Indiana'),
#   ('Woodstock', 'Illinois'),
#   ('Moreno Valley', 'California'),
#   ('El Paso', 'Texas'),
#   ('Medford', 'Oregon'),
#   ('El Paso', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Elmhurst', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Columbus', 'Ohio'),
#   ('San Diego', 'California'),
#   ('Wilmington', 'North Carolina'),
#   ('Columbia', 'South Carolina'),
#   ('Margate', 'Florida'),
#   ('Yonkers', 'New York'),
#   ('Des Moines', 'Washington'),
#   ('Seattle', 'Washington'),
#   ('Royal Oak', 'Michigan'),
#   ('Denver', 'Colorado'),
#   ('Roseville', 'California'),
#   ('Huntington Beach', 'California'),
#   ('Chesapeake', 'Virginia'),
#   ('Logan', 'Utah'),
#   ('Chicago', 'Illinois'),
#   ('Tampa', 'Florida'),
#   ('Raleigh', 'North Carolina'),
#   ('Dallas', 'Texas'),
#   ('Lakeville', 'Minnesota'),
#   ('San Francisco', 'California'),
#   ('Hamilton', 'Ohio'),
#   ('Asheville', 'North Carolina'),
#   ('Knoxville', 'Tennessee'),
#   ('Tucson', 'Arizona'),
#   ('Delray Beach', 'Florida'),
#   ('Fresno', 'California'),
#   ('New York City', 'New York'),
#   ('San Francisco', 'California'),
#   ('Pomona', 'California'),
#   ('Los Angeles', 'California'),
#   ('Des Moines', 'Iowa'),
#   ('Springfield', 'Ohio'),
#   ('Brownsville', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Apple Valley', 'Minnesota'),
#   ('San Francisco', 'California'),
#   ('Tampa', 'Florida'),
#   ('Miami', 'Florida'),
#   ('Chicago', 'Illinois'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Revere', 'Massachusetts'),
#   ('Houston', 'Texas'),
#   ('Athens', 'Georgia'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Lafayette', 'Louisiana'),
#   ('Alexandria', 'Virginia'),
#   ('Dearborn Heights', 'Michigan'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Mobile', 'Alabama'),
#   ('Marietta', 'Georgia'),
#   ('Chandler', 'Arizona'),
#   ('Concord', 'California'),
#   ('Lewiston', 'Idaho'),
#   ('Lodi', 'California'),
#   ('Redondo Beach', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Baltimore', 'Maryland'),
#   ('Los Angeles', 'California'),
#   ('Wilmington', 'North Carolina'),
#   ('Houston', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('San Jose', 'California'),
#   ('Los Angeles', 'California'),
#   ('Henderson', 'Kentucky'),
#   ('Troy', 'New York'),
#   ('San Francisco', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Wilmington', 'North Carolina'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Newark', 'Ohio'),
#   ('Baltimore', 'Maryland'),
#   ('Louisville', 'Kentucky'),
#   ('Jackson', 'Mississippi'),
#   ('Lakeland', 'Florida'),
#   ('Appleton', 'Wisconsin'),
#   ('Yonkers', 'New York'),
#   ('Houston', 'Texas'),
#   ('Jackson', 'Michigan'),
#   ('Middletown', 'Connecticut'),
#   ('San Antonio', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Lawrence', 'Massachusetts'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Henderson', 'Kentucky'),
#   ('San Francisco', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Watertown', 'New York'),
#   ('Houston', 'Texas'),
#   ('Fort Worth', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('Milwaukee', 'Wisconsin'),
#   ('Franklin', 'Massachusetts'),
#   ('West Jordan', 'Utah'),
#   ('Hialeah', 'Florida'),
#   ('Los Angeles', 'California'),
#   ('Oakland', 'California'),
#   ('Saint Petersburg', 'Florida'),
#   ('Los Angeles', 'California'),
#   ('San Francisco', 'California'),
#   ('Eau Claire', 'Wisconsin'),
#   ('Akron', 'Ohio'),
#   ('Dallas', 'Texas'),
#   ('Midland', 'Michigan'),
#   ('Dover', 'New Hampshire'),
#   ('San Diego', 'California'),
#   ('Lawrence', 'Massachusetts'),
#   ('Virginia Beach', 'Virginia'),
#   ('Decatur', 'Alabama'),
#   ('Bellevue', 'Washington'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Baltimore', 'Maryland'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Murray', 'Utah'),
#   ('Chicago', 'Illinois'),
#   ('San Diego', 'California'),
#   ('San Francisco', 'California'),
#   ('Chicago', 'Illinois'),
#   ('Seattle', 'Washington'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('Buffalo Grove', 'Illinois'),
#   ('Jackson', 'Mississippi'),
#   ('Detroit', 'Michigan'),
#   ('Lakeville', 'Minnesota'),
#   ('Seattle', 'Washington'),
#   ('Midland', 'Michigan'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('Rochester', 'New York'),
#   ('Aurora', 'Illinois'),
#   ('Bristol', 'Tennessee'),
#   ('North Las Vegas', 'Nevada'),
#   ('San Francisco', 'California'),
#   ('Los Angeles', 'California'),
#   ('Detroit', 'Michigan'),
#   ('Los Angeles', 'California'),
#   ('Detroit', 'Michigan'),
#   ('El Paso', 'Texas'),
#   ('San Antonio', 'Texas'),
#   ('Hempstead', 'New York'),
#   ('Newark', 'Delaware'),
#   ('Chicago', 'Illinois'),
#   ('Los Angeles', 'California'),
#   ('Halifax', 'Nova Scotia'),
#   ('Lawton', 'Oklahoma'),
#   ('Pueblo', 'Colorado'),
#   ('Lakewood', 'New Jersey'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Meriden', 'Connecticut'),
#   ('Waynesboro', 'Virginia'),
#   ('Phoenix', 'Arizona'),
#   ('Louisville', 'Colorado'),
#   ('Tucson', 'Arizona'),
#   ('Southaven', 'Mississippi'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Cincinnati', 'Ohio'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Wilmington', 'North Carolina'),
#   ('Deltona', 'Florida'),
#   ('Seattle', 'Washington'),
#   ('Plainfield', 'New Jersey'),
#   ('Aurora', 'Colorado'),
#   ('Jackson', 'Mississippi'),
#   ('Palm Coast', 'Florida'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Buffalo', 'New York'),
#   ('Dallas', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Los Angeles', 'California'),
#   ('Hackensack', 'New Jersey'),
#   ('New York City', 'New York'),
#   ('League City', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Newark', 'Delaware'),
#   ('New York City', 'New York'),
#   ('Phoenix', 'Arizona'),
#   ('New Rochelle', 'New York'),
#   ('Great Falls', 'Montana'),
#   ('Bristol', 'Connecticut'),
#   ('San Francisco', 'California'),
#   ('Riverside', 'California'),
#   ('Springfield', 'Ohio'),
#   ('Dallas', 'Texas'),
#   ('Dallas', 'Texas'),
#   ('Omaha', 'Nebraska'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('San Francisco', 'California'),
#   ('Tucson', 'Arizona'),
#   ('San Francisco', 'California'),
#   ('Los Angeles', 'California'),
#   ('Draper', 'Utah'),
#   ('North Las Vegas', 'Nevada'),
#   ('San Antonio', 'Texas'),
#   ('Atlanta', 'Georgia'),
#   ('Chicago', 'Illinois'),
#   ('San Francisco', 'California'),
#   ('New York City', 'New York'),
#   ('Apopka', 'Florida'),
#   ('Seattle', 'Washington'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Charlotte', 'North Carolina'),
#   ('Glendale', 'Arizona'),
#   ('Denver', 'Colorado'),
#   ('New York City', 'New York'),
#   ('Meriden', 'Connecticut'),
#   ('Columbia', 'South Carolina'),
#   ('Glendale', 'Arizona'),
#   ('Vacaville', 'California'),
#   ('Jacksonville', 'Florida'),
#   ('Seattle', 'Washington'),
#   ('Saint Petersburg', 'Florida'),
#   ('Fresno', 'California'),
#   ('San Diego', 'California'),
#   ('Lakewood', 'New Jersey'),
#   ('San Francisco', 'California'),
#   ('Woodstock', 'Georgia'),
#   ('Miami', 'Florida'),
#   ('Dallas', 'Texas'),
#   ('Hollywood', 'Florida'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Houston', 'Texas'),
#   ('Little Rock', 'Arkansas'),
#   ('Columbus', 'Ohio'),
#   ('Los Angeles', 'California'),
#   ('Jonesboro', 'Arkansas'),
#   ('Chicago', 'Illinois'),
#   ('Hampton', 'Virginia'),
#   ('Lakewood', 'Ohio'),
#   ('North Miami', 'Florida'),
#   ('Denver', 'Colorado'),
#   ('New York City', 'New York'),
#   ('Oceanside', 'New York'),
#   ('Owensboro', 'Kentucky'),
#   ('Houston', 'Texas'),
#   ('Seattle', 'Washington'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('Newark', 'Delaware'),
#   ('Newark', 'Delaware'),
#   ('Springfield', 'Virginia'),
#   ('San Francisco', 'California'),
#   ('Miami', 'Florida'),
#   ('San Francisco', 'California'),
#   ('Bristol', 'Connecticut'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('Watertown', 'New York'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('Saint Petersburg', 'Florida'),
#   ('Bowling Green', 'Ohio'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Houston', 'Texas'),
#   ('Santa Clara', 'California'),
#   ('Tulsa', 'Oklahoma'),
#   ('Macon', 'Georgia'),
#   ('San Francisco', 'California'),
#   ('San Francisco', 'California'),
#   ('San Antonio', 'Texas'),
#   ('Pasco', 'Washington'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('Lowell', 'Massachusetts'),
#   ('Chicago', 'Illinois'),
#   ('Detroit', 'Michigan'),
#   ('Greenville', 'North Carolina'),
#   ('Gresham', 'Oregon'),
#   ('Oxnard', 'California'),
#   ('New Rochelle', 'New York'),
#   ('Cary', 'North Carolina'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Tempe', 'Arizona'),
#   ('Odessa', 'Texas'),
#   ('Macon', 'Georgia'),
#   ('Corpus Christi', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Springfield', 'Oregon'),
#   ('Seattle', 'Washington'),
#   ('Chula Vista', 'California'),
#   ('Raleigh', 'North Carolina'),
#   ('San Francisco', 'California'),
#   ('Charlotte', 'North Carolina'),
#   ('Seattle', 'Washington'),
#   ('Chandler', 'Arizona'),
#   ('Houston', 'Texas'),
#   ('Long Beach', 'California'),
#   ('New York City', 'New York'),
#   ('San Diego', 'California'),
#   ('Los Angeles', 'California'),
#   ('Bloomington', 'Illinois'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Garland', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Des Moines', 'Washington'),
#   ('San Francisco', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Dover', 'Delaware'),
#   ('San Diego', 'California'),
#   ('Minneapolis', 'Minnesota'),
#   ('Aurora', 'Colorado'),
#   ('Houston', 'Texas'),
#   ('Seattle', 'Washington'),
#   ('San Diego', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Mesquite', 'Texas'),
#   ('Hackensack', 'New Jersey'),
#   ('San Diego', 'California'),
#   ('Fayetteville', 'North Carolina'),
#   ('Lawrence', 'Massachusetts'),
#   ('Hollywood', 'Florida'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Fairfield', 'Ohio'),
#   ('Reno', 'Nevada'),
#   ('Tempe', 'Arizona'),
#   ('Los Angeles', 'California'),
#   ('Evanston', 'Illinois'),
#   ('Durham', 'North Carolina'),
#   ('New York City', 'New York'),
#   ('Seattle', 'Washington'),
#   ('Vallejo', 'California'),
#   ('Pomona', 'California'),
#   ('Columbus', 'Ohio'),
#   ('San Diego', 'California'),
#   ('Indianapolis', 'Indiana'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Charlotte', 'North Carolina'),
#   ('New York City', 'New York'),
#   ('Jacksonville', 'North Carolina'),
#   ('San Francisco', 'California'),
#   ('Albuquerque', 'New Mexico'),
#   ('Huntsville', 'Texas'),
#   ('Columbus', 'Ohio'),
#   ('Phoenix', 'Arizona'),
#   ('Pasadena', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Redondo Beach', 'California'),
#   ('Fayetteville', 'Arkansas'),
#   ('San Francisco', 'California'),
#   ('Chicago', 'Illinois'),
#   ('Mount Vernon', 'New York'),
#   ('Lakewood', 'New Jersey'),
#   ('Richmond', 'Virginia'),
#   ('Chicago', 'Illinois'),
#   ('Everett', 'Massachusetts'),
#   ('Hialeah', 'Florida'),
#   ('San Francisco', 'California'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Texarkana', 'Arkansas'),
#   ('Lakewood', 'California'),
#   ('Los Angeles', 'California'),
#   ('San Francisco', 'California'),
#   ('Knoxville', 'Tennessee'),
#   ('Chicago', 'Illinois'),
#   ('Newport News', 'Virginia'),
#   ('Fairfield', 'Ohio'),
#   ('Newark', 'Ohio'),
#   ('Rancho Cucamonga', 'California'),
#   ('Fort Lauderdale', 'Florida'),
#   ('Rock Hill', 'South Carolina'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Fayetteville', 'North Carolina'),
#   ('Garden City', 'Kansas'),
#   ('Columbus', 'Indiana'),
#   ('Chicago', 'Illinois'),
#   ('Avondale', 'Arizona'),
#   ('Los Angeles', 'California'),
#   ('Lorain', 'Ohio'),
#   ('Portland', 'Oregon'),
#   ('Richmond', 'Kentucky'),
#   ('Fort Lauderdale', 'Florida'),
#   ('Medina', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Omaha', 'Nebraska'),
#   ('Jacksonville', 'North Carolina'),
#   ('Lancaster', 'Pennsylvania'),
#   ('Nashville', 'Tennessee'),
#   ('Fairfield', 'Connecticut'),
#   ('Orange', 'New Jersey'),
#   ('Cary', 'North Carolina'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('San Diego', 'California'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Hampton', 'Virginia'),
#   ('Columbus', 'Georgia'),
#   ('San Francisco', 'California'),
#   ('Houston', 'Texas'),
#   ('Wausau', 'Wisconsin'),
#   ('Midland', 'Michigan'),
#   ('San Diego', 'California'),
#   ('Louisville', 'Colorado'),
#   ('Seattle', 'Washington'),
#   ('Houston', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('Los Angeles', 'California'),
#   ('New Rochelle', 'New York'),
#   ('Reading', 'Pennsylvania'),
#   ('Carrollton', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Asheville', 'North Carolina'),
#   ('San Antonio', 'Texas'),
#   ('Chesapeake', 'Virginia'),
#   ('Fairfield', 'Connecticut'),
#   ('Midland', 'Michigan'),
#   ('New York City', 'New York'),
#   ('Pasadena', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Huntington Beach', 'California'),
#   ('Bloomington', 'Indiana'),
#   ('Manhattan', 'Kansas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Moorhead', 'Minnesota'),
#   ('Newark', 'Delaware'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Seattle', 'Washington'),
#   ('Louisville', 'Colorado'),
#   ('Minneapolis', 'Minnesota'),
#   ('Provo', 'Utah'),
#   ('Monroe', 'Louisiana'),
#   ('Jamestown', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Coon Rapids', 'Minnesota'),
#   ('Dallas', 'Texas'),
#   ('Richmond', 'Kentucky'),
#   ('San Francisco', 'California'),
#   ('San Francisco', 'California'),
#   ('Atlanta', 'Georgia'),
#   ('Columbus', 'Georgia'),
#   ('Los Angeles', 'California'),
#   ('Pasadena', 'Texas'),
#   ('Bolingbrook', 'Illinois'),
#   ('Mesquite', 'Texas'),
#   ('Scottsdale', 'Arizona'),
#   ('Detroit', 'Michigan'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Chicago', 'Illinois'),
#   ('Saint Louis', 'Missouri'),
#   ('Sacramento', 'California'),
#   ('Columbus', 'Ohio'),
#   ('Cincinnati', 'Ohio'),
#   ("St. John's", 'Newfoundland and Labrador'),
#   ('Toledo', 'Ohio'),
#   ('Woonsocket', 'Rhode Island'),
#   ('Arlington', 'Texas'),
#   ('Springfield', 'Oregon'),
#   ('Tigard', 'Oregon'),
#   ('San Francisco', 'California'),
#   ('Buffalo', 'New York'),
#   ('San Francisco', 'California'),
#   ('Richmond', 'Indiana'),
#   ('Skokie', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Avondale', 'Arizona'),
#   ('Orlando', 'Florida'),
#   ('Houston', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Jacksonville', 'North Carolina'),
#   ('Lowell', 'Massachusetts'),
#   ('Columbus', 'Ohio'),
#   ('Madison', 'Wisconsin'),
#   ('Chicago', 'Illinois'),
#   ('Corpus Christi', 'Texas'),
#   ('Moncton', 'New Brunswick'),
#   ('Oklahoma City', 'Oklahoma'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Columbus', 'Ohio'),
#   ('Chicago', 'Illinois'),
#   ('Houston', 'Texas'),
#   ('Springfield', 'Oregon'),
#   ('Memphis', 'Tennessee'),
#   ('Virginia Beach', 'Virginia'),
#   ('Seattle', 'Washington'),
#   ('Olympia', 'Washington'),
#   ('Chicago', 'Illinois'),
#   ('Mesa', 'Arizona'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Brownsville', 'Texas'),
#   ('New York City', 'New York'),
#   ('San Antonio', 'Texas'),
#   ('Fresno', 'California'),
#   ('Concord', 'California'),
#   ('Miami', 'Florida'),
#   ('Phoenix', 'Arizona'),
#   ('Los Angeles', 'California'),
#   ('Marion', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('Deltona', 'Florida'),
#   ('Springfield', 'Virginia'),
#   ('Beaumont', 'Texas'),
#   ('Detroit', 'Michigan'),
#   ('Hialeah', 'Florida'),
#   ('Columbus', 'Georgia'),
#   ('Florence', 'Alabama'),
#   ('Los Angeles', 'California'),
#   ('Chicago', 'Illinois'),
#   ('Grand Prairie', 'Texas'),
#   ('Hamilton', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Columbia', 'Tennessee'),
#   ('Indianapolis', 'Indiana'),
#   ('Thornton', 'Colorado'),
#   ('Los Angeles', 'California'),
#   ('San Diego', 'California'),
#   ('San Jose', 'California'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Port Arthur', 'Texas'),
#   ('Richmond', 'Indiana'),
#   ('Tampa', 'Florida'),
#   ('Los Angeles', 'California'),
#   ('Miami', 'Florida'),
#   ('Cleveland', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Chicago', 'Illinois'),
#   ('Skokie', 'Illinois'),
#   ('Fort Worth', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Phoenix', 'Arizona'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Beverly', 'Massachusetts'),
#   ('Kent', 'Ohio'),
#   ('Brentwood', 'California'),
#   ('Quebec City', 'Quebec'),
#   ('Cottage Grove', 'Minnesota'),
#   ('San Francisco', 'California'),
#   ('Memphis', 'Tennessee'),
#   ('Taylor', 'Michigan'),
#   ('New York City', 'New York'),
#   ('Phoenix', 'Arizona'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Reno', 'Nevada'),
#   ('Columbia', 'Missouri'),
#   ('Watertown', 'New York'),
#   ('Medina', 'Ohio'),
#   ('Dallas', 'Texas'),
#   ('Woodbury', 'Minnesota'),
#   ('San Francisco', 'California'),
#   ('Colorado Springs', 'Colorado'),
#   ('Henderson', 'Kentucky'),
#   ('Toledo', 'Ohio'),
#   ('Newark', 'Delaware'),
#   ('Columbus', 'Georgia'),
#   ('Park Ridge', 'Illinois'),
#   ('Bartlett', 'Tennessee'),
#   ('Texas City', 'Texas'),
#   ('Bozeman', 'Montana'),
#   ('West Palm Beach', 'Florida'),
#   ('Cleveland', 'Ohio'),
#   ('Concord', 'North Carolina'),
#   ('Los Angeles', 'California'),
#   ('Houston', 'Texas'),
#   ('Minneapolis', 'Minnesota'),
#   ('Rome', 'New York'),
#   ('Pleasant Grove', 'Utah'),
#   ('Columbus', 'Georgia'),
#   ('Omaha', 'Nebraska'),
#   ('Garden City', 'Kansas'),
#   ('Columbus', 'Ohio'),
#   ('Dallas', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Rochester', 'New York'),
#   ('Dover', 'New Hampshire'),
#   ('Los Angeles', 'California'),
#   ('Perth Amboy', 'New Jersey'),
#   ('Columbia', 'Maryland'),
#   ('Las Cruces', 'New Mexico'),
#   ('Seattle', 'Washington'),
#   ('Providence', 'Rhode Island'),
#   ('Altoona', 'Pennsylvania'),
#   ('Columbia', 'Tennessee'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Houston', 'Texas'),
#   ('Coppell', 'Texas'),
#   ('Richmond', 'Indiana'),
#   ('New York City', 'New York'),
#   ('Chicago', 'Illinois'),
#   ('New Castle', 'Indiana'),
#   ('Houston', 'Texas'),
#   ('San Francisco', 'California'),
#   ('Kenosha', 'Wisconsin'),
#   ('Pueblo', 'Colorado'),
#   ('Raleigh', 'North Carolina'),
#   ('Clinton', 'Maryland'),
#   ('Dover', 'New Hampshire'),
#   ('Roseville', 'California'),
#   ('Lehi', 'Utah'),
#   ('Auburn', 'Alabama'),
#   ('Atlanta', 'Georgia'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Houston', 'Texas'),
#   ('North Miami', 'Florida'),
#   ('Lancaster', 'California'),
#   ('New York City', 'New York'),
#   ('Milwaukee', 'Wisconsin'),
#   ('Jacksonville', 'North Carolina'),
#   ('Montreal', 'Quebec'),
#   ('Houston', 'Texas'),
#   ('Huntsville', 'Alabama'),
#   ('San Diego', 'California'),
#   ('Houston', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Covington', 'Washington'),
#   ('Coral Springs', 'Florida'),
#   ('Peoria', 'Illinois'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Seattle', 'Washington'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Seattle', 'Washington'),
#   ('San Diego', 'California'),
#   ('New York City', 'New York'),
#   ('Springfield', 'Virginia'),
#   ('Jacksonville', 'Florida'),
#   ('Normal', 'Illinois'),
#   ('Houston', 'Texas'),
#   ('Jacksonville', 'Florida'),
#   ('Dallas', 'Texas'),
#   ('Houston', 'Texas'),
#   ('New York City', 'New York'),
#   ('Lansing', 'Michigan'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Bristol', 'Tennessee'),
#   ('Spokane', 'Washington'),
#   ('Houston', 'Texas'),
#   ('Jacksonville', 'North Carolina'),
#   ('Long Beach', 'California'),
#   ('Sacramento', 'California'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('Norfolk', 'Nebraska'),
#   ('Glendale', 'Arizona'),
#   ('Mesa', 'Arizona'),
#   ('Farmington', 'New Mexico'),
#   ('Los Angeles', 'California'),
#   ('Toledo', 'Ohio'),
#   ('Waynesboro', 'Virginia'),
#   ('New York City', 'New York'),
#   ('Mcallen', 'Texas'),
#   ('Monroe', 'Louisiana'),
#   ('Los Angeles', 'California'),
#   ('Santa Maria', 'California'),
#   ('Carrollton', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Detroit', 'Michigan'),
#   ('Louisville', 'Kentucky'),
#   ('Los Angeles', 'California'),
#   ('New York City', 'New York'),
#   ('Aurora', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Milwaukee', 'Wisconsin'),
#   ('Daytona Beach', 'Florida'),
#   ('Houston', 'Texas'),
#   ('Washington', 'District of Columbia'),
#   ('Aurora', 'Colorado'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Chicago', 'Illinois'),
#   ('Lawrence', 'Massachusetts'),
#   ('Los Angeles', 'California'),
#   ('Houston', 'Texas'),
#   ('San Jose', 'California'),
#   ('Chula Vista', 'California'),
#   ('New York City', 'New York'),
#   ('Indianapolis', 'Indiana'),
#   ('Houston', 'Texas'),
#   ('Toronto', 'Ontario'),
#   ('Owensboro', 'Kentucky'),
#   ('Minneapolis', 'Minnesota'),
#   ('New York City', 'New York'),
#   ('Salem', 'Oregon'),
#   ('Cuyahoga Falls', 'Ohio'),
#   ('Aurora', 'Illinois'),
#   ('Louisville', 'Colorado'),
#   ('San Francisco', 'California'),
#   ('Louisville', 'Colorado'),
#   ('Houston', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('Los Angeles', 'California'),
#   ('Camarillo', 'California'),
#   ('Chester', 'Pennsylvania'),
#   ('Roswell', 'Georgia'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Long Beach', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('Phoenix', 'Arizona'),
#   ('Columbia', 'South Carolina'),
#   ('Woonsocket', 'Rhode Island'),
#   ('Naperville', 'Illinois'),
#   ('Pueblo', 'Colorado'),
#   ('Columbia', 'Tennessee'),
#   ('Wichita', 'Kansas'),
#   ('San Antonio', 'Texas'),
#   ('Bellevue', 'Washington'),
#   ('Rochester', 'New York'),
#   ('Manchester', 'Connecticut'),
#   ('Seattle', 'Washington'),
#   ('Indianapolis', 'Indiana'),
#   ('Cleveland', 'Ohio'),
#   ('Springfield', 'Virginia'),
#   ('New York City', 'New York'),
#   ('Minneapolis', 'Minnesota'),
#   ('San Jose', 'California'),
#   ('Norwich', 'Connecticut'),
#   ('Fayetteville', 'North Carolina'),
#   ('Long Beach', 'New York'),
#   ('Detroit', 'Michigan'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Saint Charles', 'Missouri'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Los Angeles', 'California'),
#   ('Saint Petersburg', 'Florida'),
#   ('Pocatello', 'Idaho'),
#   ('Royal Oak', 'Michigan'),
#   ('Hampton', 'Virginia'),
#   ('Lakeland', 'Florida'),
#   ('Monroe', 'Louisiana'),
#   ('Newark', 'Delaware'),
#   ('Columbus', 'Indiana'),
#   ('Decatur', 'Alabama'),
#   ('Lewiston', 'Maine'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Gilbert', 'Arizona'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Grand Prairie', 'Texas'),
#   ('Peoria', 'Arizona'),
#   ('Miami', 'Florida'),
#   ('San Diego', 'California'),
#   ('Smyrna', 'Tennessee'),
#   ('Los Angeles', 'California'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Deltona', 'Florida'),
#   ('Layton', 'Utah'),
#   ('Rochester', 'New York'),
#   ('Long Beach', 'California'),
#   ('East Point', 'Georgia'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Houston', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Lakewood', 'Ohio'),
#   ('Richmond', 'Virginia'),
#   ('Gilbert', 'Arizona'),
#   ('Lancaster', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Carol Stream', 'Illinois'),
#   ('Hollywood', 'Florida'),
#   ('New York City', 'New York'),
#   ('Houston', 'Texas'),
#   ('Richmond', 'Kentucky'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Sterling Heights', 'Michigan'),
#   ('Fayetteville', 'North Carolina'),
#   ('Pasadena', 'California'),
#   ('New York City', 'New York'),
#   ('Holyoke', 'Massachusetts'),
#   ('Vineland', 'New Jersey'),
#   ('Houston', 'Texas'),
#   ('Dallas', 'Texas'),
#   ('Clinton', 'Maryland'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Franklin', 'Massachusetts'),
#   ('Nashville', 'Tennessee'),
#   ('Tempe', 'Arizona'),
#   ('Wilmington', 'Delaware'),
#   ('Seattle', 'Washington'),
#   ('Chicago', 'Illinois'),
#   ('Amarillo', 'Texas'),
#   ('Mesa', 'Arizona'),
#   ('Baltimore', 'Maryland'),
#   ('San Francisco', 'California'),
#   ('Bakersfield', 'California'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Highland Park', 'Illinois'),
#   ('New York City', 'New York'),
#   ('Louisville', 'Kentucky'),
#   ('Los Angeles', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Mesa', 'Arizona'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Oxnard', 'California'),
#   ('Lakeville', 'Minnesota'),
#   ('Houston', 'Texas'),
#   ('San Francisco', 'California'),
#   ('New York City', 'New York'),
#   ('Hattiesburg', 'Mississippi'),
#   ('Saint Louis', 'Missouri'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('Dallas', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Kirkwood', 'Missouri'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Bakersfield', 'California'),
#   ('San Francisco', 'California'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('Milwaukee', 'Wisconsin'),
#   ('Jacksonville', 'Florida'),
#   ('Redmond', 'Oregon'),
#   ('Raleigh', 'North Carolina'),
#   ('New York City', 'New York'),
#   ('Greensboro', 'North Carolina'),
#   ('Richmond', 'Indiana'),
#   ('Marietta', 'Georgia'),
#   ('Los Angeles', 'California'),
#   ('Phoenix', 'Arizona'),
#   ('Florence', 'Kentucky'),
#   ('San Francisco', 'California'),
#   ('Allentown', 'Pennsylvania'),
#   ('San Francisco', 'California'),
#   ('Springfield', 'Ohio'),
#   ('New York City', 'New York'),
#   ('Bolingbrook', 'Illinois'),
#   ('Bowling Green', 'Ohio'),
#   ('Florence', 'Kentucky'),
#   ('New York City', 'New York'),
#   ('Arlington', 'Texas'),
#   ('Houston', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('San Diego', 'California'),
#   ('Los Angeles', 'California'),
#   ('Dallas', 'Texas'),
#   ('Chicago', 'Illinois'),
#   ('Fairfield', 'Connecticut'),
#   ('Detroit', 'Michigan'),
#   ('San Diego', 'California'),
#   ('Los Angeles', 'California'),
#   ('Los Angeles', 'California'),
#   ('San Francisco', 'California'),
#   ('San Francisco', 'California'),
#   ('Durham', 'North Carolina'),
#   ('Tucson', 'Arizona'),
#   ('Houston', 'Texas'),
#   ('Medford', 'Oregon'),
#   ('Houston', 'Texas'),
#   ('San Diego', 'California'),
#   ('Rochester', 'Minnesota'),
#   ('Richmond', 'Virginia'),
#   ('Tamarac', 'Florida'),
#   ('Seattle', 'Washington'),
#   ('La Quinta', 'California'),
#   ('New York City', 'New York'),
#   ('New York City', 'New York'),
#   ('El Paso', 'Texas'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Pasadena', 'California'),
#   ('Montgomery', 'Alabama'),
#   ('Los Angeles', 'California'),
#   ('Austin', 'Texas'),
#   ('Los Angeles', 'California'),
#   ('Revere', 'Massachusetts'),
#   ('Paterson', 'New Jersey'),
#   ('Aurora', 'Colorado'),
#   ('Redlands', 'California'),
#   ('New York City', 'New York'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Anaheim', 'California'),
#   ('Chicago', 'Illinois'),
#   ('Atlanta', 'Georgia'),
#   ('North Charleston', 'South Carolina'),
#   ('Los Angeles', 'California'),
#   ('Des Moines', 'Iowa'),
#   ('Provo', 'Utah'),
#   ('Coral Springs', 'Florida'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('New York City', 'New York'),
#   ('Los Angeles', 'California'),
#   ('Seattle', 'Washington'),
#   ('Houston', 'Texas'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('San Diego', 'California'),
#   ('Clinton', 'Maryland'),
#   ('Long Beach', 'California'),
#   ('Des Moines', 'Washington'),
#   ('Los Angeles', 'California'),
#   ('Santa Fe', 'New Mexico'),
#   ('Columbus', 'Georgia'),
#   ('Sacramento', 'California'),
#   ('Naperville', 'Illinois'),
#   ('Nashville', 'Tennessee'),
#   ('Las Vegas', 'Nevada'),
#   ('Lawrence', 'Massachusetts'),
#   ('Long Beach', 'New York'),
#   ('Quincy', 'Massachusetts'),
#   ('Seattle', 'Washington'),
#   ('Oceanside', 'California'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Philadelphia', 'Pennsylvania'),
#   ('Seattle', 'Washington'),
#   ('New York City', 'New York'),
#   ('Avondale', 'Arizona'),
#   ('Tucson', 'Arizona'),
#   ('Columbus', 'Ohio'),
#   ...])

# %% [markdown]
# ## Unable to save changes in the jupyter notebook file

# %% [markdown]
# I randomely faced an issue where I was not able to save any changes I made in my jupyter notebook. <br>
# I googled about this issue and found out :
# - I found out that windows doesn't allow you to make changes to a file if another program is using it. In my case this was irrelevant because only jupyter notebook was the only program accessing this file. I haven't opened this file on any other application.
# - I used this code to check if the file acutally exists or not in the directory where its supposed to be ```import os
# os.path.exists(r"D:\training\credencys-training-pyspark\python\database_operation")``` I got the result to be True.
# - I opened the directory in file manager where I noticed there were two temp files that were present in that directory. I simply deleted it. Deleting the temp files resolved this issue.
#
# <br>
#
# I still don't know why this glitch happened. I will look into it at a later date. This has never happend to be before when I used to use jupyter notebook on linux platforms.
#
# <br>
#
# **NOTICE:** It took a bit more time to resolve this issue and I found the solution by accident.

# %%
conn = psycopg2.connect(
    host="localhost",
    database="training",
    user="postgres",
    password="1212",
    port=5432
)
conn


    

# Open a cursor to perform database operations
cur = conn.cursor()
# Execute a command: create datacamp_courses table
cur.execute("""CREATE TABLE datacamp_courses(
            course_id SERIAL PRIMARY KEY,
            course_name VARCHAR (50) UNIQUE NOT NULL,
            course_instructor VARCHAR (100) NOT NULL,
            topic VARCHAR (20) NOT NULL);
            """)
# Make the changes to the database persistent
conn.commit()
# Close cursor and communication with the database
cur.close()
conn.close()
